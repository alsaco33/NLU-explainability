# %% [markdown]
# # Installs

# %%
# !pip install transformers
# !pip install shap
# !pip install lime
# !pip install sentencepiece 
# !pip install emoji
# !pip install rouge_score
# !pip install captum
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.29.1-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 44.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 13.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 66.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.14.1 tokenizers-0.13.3 transformers-4.29.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting shap
#   Downloading shap-0.41.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.6/572.6 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.3)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.65.0)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.1)
# Collecting slicer==0.0.7 (from shap)
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.56.4)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->shap) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.41.0 slicer-0.0.7
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting lime
#   Downloading lime-0.2.0.1.tar.gz (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from lime) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lime) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lime) (1.10.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from lime) (4.65.0)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.10/dist-packages (from lime) (1.2.2)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.10/dist-packages (from lime) (0.19.3)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (3.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (8.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (23.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->lime) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->lime) (3.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->lime) (1.16.0)
# Building wheels for collected packages: lime
#   Building wheel for lime (setup.py) ... done
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283839 sha256=4bdde9624389b87fff297af1bd32593d03eb8d0588dccb7a7cdd681bf5952641
#   Stored in directory: /root/.cache/pip/wheels/fd/a2/af/9ac0a1a85a27f314a06b39e1f492bee1547d52549a4606ed89
# Successfully built lime
# Installing collected packages: lime
# Successfully installed lime-0.2.0.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.1 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting emoji
#   Downloading emoji-2.2.0.tar.gz (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.9/240.9 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-2.2.0-py3-none-any.whl size=234911 sha256=e33405a36dc271725a4519ce9b50bd0ff5cd0c5c6182d59f199bb848714e2959
#   Stored in directory: /root/.cache/pip/wheels/02/3d/88/51a592b9ad17e7899126563698b4e3961983ebe85747228ba6
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-2.2.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.22.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.65.0)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=162e1943ea64bd28be52e177129e394349b5b9f6f36d0d2754f24b9d77f7d744
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting captum
#   Downloading captum-0.6.0-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from captum) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from captum) (1.22.4)
# Requirement already satisfied: torch>=1.6 in /usr/local/lib/python3.10/dist-packages (from captum) (2.0.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->captum) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->captum) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->captum) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->captum) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->captum) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->captum) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6->captum) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6->captum) (16.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->captum) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6->captum) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6->captum) (1.3.0)
# Installing collected packages: captum
# Successfully installed captum-0.6.0

# %%
# General purpose packages
import json
import matplotlib.pyplot as plt
import numpy as np
import os
import pickle
import pandas as pd
import pprint
import re
import seaborn as sns
from tqdm import tqdm
from pprint import pprint
from math import exp
from functools import partial
from typing import Any, Dict, List

# Required imports for the supervised models
import torch
import sentencepiece
import transformers
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification, TFAutoModelForSequenceClassification

# Required imports for the explainability frameworks
import shap
from lime.lime_text import LimeTextExplainer
from captum.attr import (LayerIntegratedGradients, ShapleyValueSampling, Occlusion, 
                         LayerDeepLiftShap, TokenReferenceBase, LayerGradientXActivation, LimeBase)
from captum._utils.models.linear_model import SkLearnLasso, SkLearnLinearModel

# Import to connect with google drive's content
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 0. Define the configuration

# %%
# GLOBAL CONFIGURATION
IS_ALE       = False
BASE_PATH    = "drive/MyDrive/NLU Spring 2023 - Final Project" if IS_ALE else "drive/MyDrive/NYU/NLU Spring 2023 - Final Project"
DATA_PATH    = f"{BASE_PATH}/data"
RESULTS_PATH = f"{BASE_PATH}/results"
DATASET      = "1. Tweet Sentiment" # One of ["1. Tweet Sentiment", "2. Movie Rationales"] 
SUBSAMPLE    = True

SUPERVISED_MODELS = [
          "distilbert-base-uncased-finetuned-sst-2-english", # POSITIVE, NEGATIVE -  https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english
          "cardiffnlp/twitter-roberta-base-sentiment", # LABEL_0, LABEL_1, LABEL_2 - https://huggingface.co/cardiffnlp/twitter-roberta-base-sentiment
          "ProsusAI/finbert", # Positive, Negative, Neutral - https://huggingface.co/ProsusAI/finbert 
          "cardiffnlp/twitter-xlm-roberta-base-sentiment", # Positive, Negative, Neutral - https://huggingface.co/cardiffnlp/twitter-xlm-roberta-base-sentiment
          "finiteautomata/bertweet-base-sentiment-analysis", # Pos, Neu, Neg - https://huggingface.co/finiteautomata/bertweet-base-sentiment-analysis 
          "yiyanghkust/finbert-tone", # https://huggingface.co/yiyanghkust/finbert-tone
          ]

EMBEDDINGS = {'distilbert-base-uncased-finetuned-sst-2-english': 'model.distilbert.embeddings',
              'cardiffnlp/twitter-roberta-base-sentiment': 'model.roberta.embeddings',
              'ProsusAI/finbert': 'model.bert.embeddings',
              'cardiffnlp/twitter-xlm-roberta-base-sentiment': 'model.roberta.embeddings',
              'finiteautomata/bertweet-base-sentiment-analysis': 'model.roberta.embeddings',
              'cardiffnlp/twitter-roberta-base-sentiment-latest': 'model.roberta.embeddings',
              'yiyanghkust/finbert-tone': 'model.bert.embeddings',
              'j-hartmann/emotion-english-distilroberta-base': 'model.roberta.embeddings'}

N_EXPL_MODELS = 5

# %% [markdown]
# # 1. Load & Prep Data

# %% [markdown]
# ## 1.1 Sentiment Datasets

# %%
train_data = pd.read_csv(f"{DATA_PATH}/{DATASET}/train.csv")
test_data  = pd.read_csv(f"{DATA_PATH}/{DATASET}/test.csv")

train_data  = train_data[train_data.sentiment != 'neutral'].reset_index(drop=True)
test_data   = test_data[test_data.sentiment != 'neutral'].reset_index(drop=True)

train_data[:1000].head(2)
# Out:
#        textID                                            text selected_text  \
# 0  549e992a42   Sooo SAD I will miss you here in San Diego!!!      Sooo SAD
# 1  088c60f138                       my boss is bullying me...   bullying me
#
#   sentiment
# 0  negative
# 1  negative

# %% [markdown]
# ## 1.2 Metrics Results

# %%
with open(f'{RESULTS_PATH}/consolidated_metrics.pickle', "rb") as input_file:
  results_df = pickle.load(input_file)

# %% [markdown]
# ## 1.3 Enrichments

# %% [markdown]
# ### 1.3.1 Gold Truth
#
# - We have predicted_label but not gold_label
# - Adding it so that we can compare being aware of whether explanations are ok or not

# %%
gold_sentiments_df = train_data[:1000][['text', 'sentiment']]
gold_sentiments_df.head(5)
# Out:
#                                                 text sentiment
# 0      Sooo SAD I will miss you here in San Diego!!!  negative
# 1                          my boss is bullying me...  negative
# 2                     what interview! leave me alone  negative
# 3   Sons of ****, why couldn`t they put them on t...  negative
# 4  2am feedings for the baby are fun when he is a...  positive

# %%
results_df = gold_sentiments_df.merge(results_df, left_on='text', right_on='texts').drop(columns=['text']).rename(columns={'sentiment':'gold_label'})

assert results_df.shape[0] == results_df.shape[0]
results_df.head()
# Out:
#   gold_label                                           texts selected_text  \
# 0   negative   Sooo SAD I will miss you here in San Diego!!!      Sooo SAD
# 1   negative   Sooo SAD I will miss you here in San Diego!!!      Sooo SAD
# 2   negative   Sooo SAD I will miss you here in San Diego!!!      Sooo SAD
# 3   negative   Sooo SAD I will miss you here in San Diego!!!      Sooo SAD
# 4   negative   Sooo SAD I will miss you here in San Diego!!!      Sooo SAD
#
#                                   supervised_model expl_framework  \
# 0  distilbert-base-uncased-finetuned-sst-2-english            dls
# 1  distilbert-base-uncased-finetuned-sst-2-english            lga
# 2  distilbert-base-uncased-finetuned-sst-2-english            lig
# 3  distilbert-base-uncased-finetuned-sst-2-english            svs
# 4  distilbert-base-uncased-finetuned-sst-2-english      occlusion
#
#   predicted_label predicted_score  \
# 0        positive       0.9712993
# 1        positive       0.9712993
# 2        positive       0.9712993
# 3        positive       0.9712993
# 4        positive       0.9712993
#
#                                         explanations  feature_agreement  \
# 0  [(soo, 0.3549332), (##o, 0.30059725), (sad, 0....               0.75
# 1  [(soo, 0.31141877), (##o, 0.1204984), (sad, -0...               0.25
# 2  [(soo, -0.012404737950991807), (##o, 0.1181876...               0.50
# 3  [(soo, -0.13176894), (##o, 0.16634446), (sad, ...               0.25
# 4  [(soo, 0.0727059), (##o, 0.12056129), (sad, -0...               0.50
#
#    rank_correlation       iou       pgi       pgu
# 0          0.712525  0.750000  0.014216  0.828882
# 1          0.323875  0.166667  0.970639  0.014108
# 2          0.496609  0.400000  0.011803  0.943905
# 3          0.107958  0.166667  0.010338  0.014171
# 4          0.280692  0.400000  0.101122  0.010491

# %% [markdown]
# ### 1.3.3 Length Gold Truth

# %%
split_by   = ' |(\.)|(!)'
tokenize   = lambda x: [token for token in re.split(split_by, x) if token]
len_tokens = lambda x: len([token for token in re.split(split_by, x) if token])
results_df['len_selected_text'] = results_df.apply(lambda row : len_tokens(row['selected_text']), axis = 1)
results_df['len_selected_text'].describe()
# Out:
# count    24000.00000
# mean         4.14800
# std          4.80136
# min          1.00000
# 25%          1.00000
# 50%          2.00000
# 75%          5.00000
# max         33.00000
# Name: len_selected_text, dtype: float64

# %% [markdown]
# ### 1.3.2 Top k Explanations
#
# - Adding two fields for easier interpretation:
#     - 'explanations_top_k' (top k tokens according to explanation)
#     - 'explanations_top_k_weighted' (tuples of top k tokens with its explanations weights)

# %%
k     = 4
#top_k = lambda explanation: sorted([explanation[i][0] for i in range(len(explanation))])[-k:]
top_k_weighted   = lambda explanation: sorted(explanation, key=lambda x: x[1])[-k:] 
top_k_unweighted = lambda explanation: [token for token,_ in sorted(explanation, key=lambda x: x[1])[-k:]] 
results_df['explanations_top_k_weighted'] = results_df.apply(lambda row : top_k_weighted(row['explanations']), axis = 1)
results_df['explanations_top_k']          = results_df.apply(lambda row : top_k_unweighted(row['explanations']), axis = 1)
#results_df['explanations_top_k_unweighted'].head()

# %%
results_df.explanations_top_k.head()
# Out:
# 0      [will, ##o, soo, sad]
# 1    [you, diego, will, soo]
# 2        [##o, !, will, sad]
# 3         [in, i, ##o, will]
# 4        [soo, ##o, i, will]
# Name: explanations_top_k, dtype: object

# %%
results_df.explanations_top_k_weighted.head()
# Out:
# 0    [(will, 0.21889164), (##o, 0.30059725), (soo, ...
# 1    [(you, 0.1848618), (diego, 0.23099518), (will,...
# 2    [(##o, 0.11818761845681205), (!, 0.15467893583...
# 3    [(in, 0.07903138), (i, 0.11906659), (##o, 0.16...
# 4    [(soo, 0.0727059), (##o, 0.12056129), (i, 0.21...
# Name: explanations_top_k_weighted, dtype: object

# %% [markdown]
# ## 1.4 Bad Models/Predictions Indexes
#
# - Bad model: model where the majority (>50%) of their predictions are wrong.In this case, the only model that lies there is: 'finiteautomata/bertweet-base-sentiment-analysis'
#
# - Bad prediction: prediction where predicted label does not match the ground truth label.
#
# - For the purpose of the final analysis and insights, I will create 3 indexes to easily access the following subgroups of rows and be able to compare if any differences:
#   - 'good_model_idx': indexes good models (ie accuracy >50%)
#   - 'good_prediction_idx': indexes good predictions (ie ground truth label equals predicted label)
#   - 'good_model_good_prediction_idx': indexes good models+good predictions.

# %%
results_df['good_prediction'] = results_df.predicted_label == results_df.gold_label
results_df.good_prediction.value_counts()
# Out:
# True     16740
# False     7260
# Name: good_prediction, dtype: int64

# %%
print('Wrong Predictions per model (out of 1000): ')
results_df[~ results_df.good_prediction].supervised_model.value_counts() / N_EXPL_MODELS
# Out:
# Wrong Predictions per model (out of 1000):
# finiteautomata/bertweet-base-sentiment-analysis    764.4
# distilbert-base-uncased-finetuned-sst-2-english    242.4
# cardiffnlp/twitter-roberta-base-sentiment          229.2
# cardiffnlp/twitter-xlm-roberta-base-sentiment      216.0
# Name: supervised_model, dtype: float64

# %% [markdown]
# Model "finiteautomata/bertweet-base-sentiment-analysis" is either very bad or our labels are flipped, however even if flipped we will have over 300 "wrong predictions". So for now I think I would remove this model from the analysis.

# %%
bad_models = ['finiteautomata/bertweet-base-sentiment-analysis']
results_df['good_model'] = ~results_df.supervised_model.isin(bad_models)#.reset_index(drop=True)
results_df[results_df.good_model].supervised_model.value_counts()
# Out:
# distilbert-base-uncased-finetuned-sst-2-english    6000
# cardiffnlp/twitter-roberta-base-sentiment          6000
# cardiffnlp/twitter-xlm-roberta-base-sentiment      6000
# Name: supervised_model, dtype: int64

# %%
# Indexes to use during our analysis
good_model_idx                 = results_df['good_model']
good_prediction_idx            = results_df['good_prediction']
good_model_good_prediction_idx = good_model_idx & good_prediction_idx

# %%
results_df[good_model_idx].head(1)
# Out:
#   gold_label                                           texts selected_text  \
# 0   negative   Sooo SAD I will miss you here in San Diego!!!      Sooo SAD
#
#                                   supervised_model expl_framework  \
# 0  distilbert-base-uncased-finetuned-sst-2-english            dls
#
#   predicted_label predicted_score  \
# 0        positive       0.9712993
#
#                                         explanations  feature_agreement  \
# 0  [(soo, 0.3549332), (##o, 0.30059725), (sad, 0....               0.75
#
#    rank_correlation   iou       pgi       pgu  len_selected_text  \
# 0          0.712525  0.75  0.014216  0.828882                  2
#
#                          explanations_top_k_weighted     explanations_top_k  \
# 0  [(will, 0.21889164), (##o, 0.30059725), (soo, ...  [will, ##o, soo, sad]
#
#    good_prediction  good_model
# 0            False        True

# %%
# Even when removing the bad model, we have a balanced number of predictions
results_df[good_model_good_prediction_idx].supervised_model.value_counts()
# Out:
# cardiffnlp/twitter-xlm-roberta-base-sentiment      4920
# cardiffnlp/twitter-roberta-base-sentiment          4854
# distilbert-base-uncased-finetuned-sst-2-english    4788
# Name: supervised_model, dtype: int64

# %%
results_df[good_model_good_prediction_idx].expl_framework.value_counts()
# Out:
# dls          2427
# lga          2427
# lig          2427
# svs          2427
# occlusion    2427
# random       2427
# Name: expl_framework, dtype: int64

# %%
results_df.columns
# Out:
# Index(['gold_label', 'texts', 'selected_text', 'supervised_model',
#        'expl_framework', 'predicted_label', 'predicted_score', 'explanations',
#        'feature_agreement', 'rank_correlation', 'iou', 'pgi', 'pgu',
#        'len_selected_text', 'explanations_top_k_weighted',
#        'explanations_top_k', 'good_prediction', 'good_model'],
#       dtype='object')

# %% [markdown]
# # 2. Metrics Descriptive Stats

# %% [markdown]
# ## 2.0 Sorting+Renaming
#
# - This is just for consistency across the charts + convenience on shorter names

# %%
# Sort by expl method order
results_df.expl_framework=pd.Categorical(results_df.expl_framework,categories=['random', 'dls', 'lga', 'lig', 'occlusion', 'svs'])
results_df = results_df.sort_values('expl_framework')

# Rename feature agreement
results_df.rename(columns={'feature_agreement': 'fa(k=4)'}, inplace=True, errors='raise')
results_df.columns
# Out:
# Index(['gold_label', 'texts', 'selected_text', 'supervised_model',
#        'expl_framework', 'predicted_label', 'predicted_score', 'explanations',
#        'fa(k=4)', 'rank_correlation', 'iou', 'pgi', 'pgu', 'len_selected_text',
#        'explanations_top_k_weighted', 'explanations_top_k', 'good_prediction',
#        'good_model'],
#       dtype='object')

# %% [markdown]
# ## 2.1 Single Metric Per Supervised Model
#
# - As it can be seen, depending on the metric of interest, there is a different model that performs better overall:
#   - For our models:distilbert having the best performance on: FA, IOU and PGU
#   - twitter-roberta does the best for PGI (significantly better) and distibert the worst among all

# %%
# Means
results_df[results_df.expl_framework!='random'].groupby(['supervised_model'])['fa(k=4)','iou','pgi','pgu'].agg(['mean']).round(3) #min', 'max','mean', 'median', 'std'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                                                 fa(k=4)    iou    pgi    pgu
#                                                    mean   mean   mean   mean
# supervised_model
# cardiffnlp/twitter-roberta-base-sentiment         0.203  0.098  0.517  0.504
# cardiffnlp/twitter-xlm-roberta-base-sentiment     0.238  0.126  0.246  0.241
# distilbert-base-uncased-finetuned-sst-2-english   0.266  0.146  0.213  0.145
# finiteautomata/bertweet-base-sentiment-analysis   0.243  0.136  0.327  0.312

# %%
# Std
results_df[results_df.expl_framework!='random'].groupby(['supervised_model'])['fa(k=4)','iou','pgi','pgu'].agg(['std']).round(3) #min', 'max','mean', 'median', 'std'])
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                                                 fa(k=4)    iou    pgi    pgu
#                                                     std    std    std    std
# supervised_model
# cardiffnlp/twitter-roberta-base-sentiment         0.358  0.198  0.263  0.258
# cardiffnlp/twitter-xlm-roberta-base-sentiment     0.371  0.228  0.192  0.190
# distilbert-base-uncased-finetuned-sst-2-english   0.385  0.239  0.354  0.296
# finiteautomata/bertweet-base-sentiment-analysis   0.375  0.240  0.355  0.356

# %% [markdown]
# ## 2.2 Single Metric per Expl Framework per model (Barchart section)
#
# Insights looking across models:
# - Seeing the two twitter models, it seems to be that twitter-xlm-roberta does much better on groud-truth faithfulness (FA, IOU) and PGU than its counterpart twitter-roberta, however, the latter has higher PGI on average.
# - TODO...

# %%
show_model_metrics = lambda df, model_name: df[df.supervised_model==model_name].groupby(['supervised_model', 'expl_framework'])['fa(k=4)','iou','pgi','pgu'].agg(['mean']).round(3)

# %% [markdown]
# ### 2.2.1 cardiffnlp/twitter-roberta-base-sentiment
#
# - Occlusion seems to be maximizing FA, IOU and PGI.
# - On PGU, top performer is LGA although not that significant with respect to the others.

# %%
model_name = 'cardiffnlp/twitter-roberta-base-sentiment'
show_model_metrics(results_df, model_name)
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                                                          fa(k=4)    iou  \
#                                                             mean   mean
# supervised_model                          expl_framework
# cardiffnlp/twitter-roberta-base-sentiment random           0.156  0.071
#                                           dls              0.164  0.075
#                                           lga              0.162  0.076
#                                           lig              0.201  0.097
#                                           occlusion        0.251  0.123
#                                           svs              0.238  0.118
#
#                                                             pgi    pgu
#                                                            mean   mean
# supervised_model                          expl_framework
# cardiffnlp/twitter-roberta-base-sentiment random          0.502  0.498
#                                           dls             0.504  0.517
#                                           lga             0.521  0.486
#                                           lig             0.505  0.513
#                                           occlusion       0.532  0.503
#                                           svs             0.524  0.503

# %%
# Heatmap per model
model_name    = 'cardiffnlp/twitter-roberta-base-sentiment'
model_metrics = show_model_metrics(results_df, model_name)
model_metrics.columns = model_metrics.columns.get_level_values(0)
ax = sns.heatmap(model_metrics.loc[model_name], annot=True, cmap="crest") #set vmin and vmax if we want to fix the axes values 
ax.set(xlabel="", ylabel="") #Set ylabel=model_name if we want title
ax.xaxis.tick_top()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %% [markdown]
# ### 2.2.2 cardiffnlp/twitter-xlm-roberta-base-sentiment
#
# - Occlusion seems to be best performer across all metrics (maximizing FA, IOU and PGI, minimizing PGU)

# %%
model_name = 'cardiffnlp/twitter-xlm-roberta-base-sentiment'
show_model_metrics(results_df, model_name)
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                                                              fa(k=4)    iou  \
#                                                                 mean   mean
# supervised_model                              expl_framework
# cardiffnlp/twitter-xlm-roberta-base-sentiment random           0.214  0.114
#                                               dls              0.233  0.123
#                                               lga              0.232  0.120
#                                               lig              0.240  0.127
#                                               occlusion        0.265  0.147
#                                               svs              0.218  0.113
#
#                                                                 pgi    pgu
#                                                                mean   mean
# supervised_model                              expl_framework
# cardiffnlp/twitter-xlm-roberta-base-sentiment random          0.247  0.243
#                                               dls             0.238  0.249
#                                               lga             0.240  0.248
#                                               lig             0.237  0.239
#                                               occlusion       0.272  0.224
#                                               svs             0.244  0.243

# %%
# Heatmap per model
model_name    = 'cardiffnlp/twitter-roberta-base-sentiment'
model_metrics = show_model_metrics(results_df, model_name)
model_metrics.columns = model_metrics.columns.get_level_values(0)
ax = sns.heatmap(model_metrics.loc[model_name], annot=True, cmap="crest") #set vmin and vmax if we want to fix the axes values 
ax.set(xlabel="", ylabel="") #Set ylabel=model_name if we want title
ax.xaxis.tick_top()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %% [markdown]
# ### 2.2.3 distilbert-base-uncased-finetuned-sst-2-english
#
# - Occlusion outperforming for feature agreement+IOU, SVS for PGI and LGA for PGU.

# %%
model_name = 'distilbert-base-uncased-finetuned-sst-2-english'
show_model_metrics(results_df, model_name)
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                                                                fa(k=4)    iou  \
#                                                                   mean   mean
# supervised_model                                expl_framework
# distilbert-base-uncased-finetuned-sst-2-english random           0.221  0.119
#                                                 dls              0.243  0.132
#                                                 lga              0.256  0.139
#                                                 lig              0.278  0.154
#                                                 occlusion        0.281  0.155
#                                                 svs              0.270  0.152
#
#                                                                   pgi    pgu
#                                                                  mean   mean
# supervised_model                                expl_framework
# distilbert-base-uncased-finetuned-sst-2-english random          0.160  0.175
#                                                 dls             0.189  0.151
#                                                 lga             0.218  0.132
#                                                 lig             0.210  0.146
#                                                 occlusion       0.211  0.150
#                                                 svs             0.237  0.144

# %%
# Heatmap per model
model_name = 'distilbert-base-uncased-finetuned-sst-2-english'
model_metrics = show_model_metrics(results_df, model_name)
model_metrics.columns = model_metrics.columns.get_level_values(0)
ax = sns.heatmap(model_metrics.loc[model_name], annot=True, cmap="crest") #set vmin and vmax if we want to fix the axes values 
ax.set(xlabel="", ylabel="") #Set ylabel=model_name if we want title
ax.xaxis.tick_top()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %% [markdown]
# ### 2.2.4 finiteautomata/bertweet-base-sentiment-analysis
#
# - SVS outperforming (2nd occlusion) on FA
# - SVS and Occlusion best performance on IOU
# - Occlusion top performer on PGI
# - LGA top performer on PGU

# %%
model_name = 'finiteautomata/bertweet-base-sentiment-analysis'
show_model_metrics(results_df, model_name)
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                                                                fa(k=4)    iou  \
#                                                                   mean   mean
# supervised_model                                expl_framework
# finiteautomata/bertweet-base-sentiment-analysis random           0.205  0.116
#                                                 dls              0.233  0.132
#                                                 lga              0.232  0.131
#                                                 lig              0.219  0.126
#                                                 occlusion        0.262  0.146
#                                                 svs              0.268  0.146
#
#                                                                   pgi    pgu
#                                                                  mean   mean
# supervised_model                                expl_framework
# finiteautomata/bertweet-base-sentiment-analysis random          0.317  0.298
#                                                 dls             0.305  0.320
#                                                 lga             0.355  0.283
#                                                 lig             0.308  0.324
#                                                 occlusion       0.346  0.310
#                                                 svs             0.322  0.323

# %%
# Heatmap per model
model_name = 'finiteautomata/bertweet-base-sentiment-analysis'
model_metrics = show_model_metrics(results_df, model_name)
model_metrics.columns = model_metrics.columns.get_level_values(0)
ax = sns.heatmap(model_metrics.loc[model_name], annot=True, cmap="crest") #set vmin and vmax if we want to fix the axes values 
ax.set(xlabel="", ylabel="") #Set ylabel=model_name if we want title
ax.xaxis.tick_top()
# Out:
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %% [markdown]
# ## 2.3 Heatmaps for each metric

# %% [markdown]
# ### 2.3.1 fa(k=4)

# %%
# Metric Per model/expl method
metric_name = 'fa(k=4)'
means       = results_df.groupby(['supervised_model', 'expl_framework'])[metric_name].agg(['mean'], axis=0).round(3) #min', 'max','mean', 'median', 'std'])
means       = means.reset_index().pivot(index='supervised_model', columns='expl_framework', values='mean')
ax = sns.heatmap(means, annot=True, cmap="crest") #vmin=50, vmax=100) 
ax.set(xlabel="", ylabel='') #ylabel = metric_name)
ax.xaxis.tick_top()

# %% [markdown]
# ### 2.3.2 IOU

# %%
# Metric Per model/expl method
metric_name = 'iou'
means       = results_df.groupby(['supervised_model', 'expl_framework'])[metric_name].agg(['mean'], axis=0).round(3) #min', 'max','mean', 'median', 'std'])
means       = means.reset_index().pivot(index='supervised_model', columns='expl_framework', values='mean')
ax = sns.heatmap(means, annot=True, cmap="crest") #vmin=50, vmax=100) 
ax.set(xlabel="", ylabel='') #ylabel = metric_name)
ax.xaxis.tick_top()

# %% [markdown]
# ### 2.3.3 PGI

# %%
# Metric Per model/expl method
metric_name = 'pgi'
means       = results_df.groupby(['supervised_model', 'expl_framework'])[metric_name].agg(['mean'], axis=0).round(3) #min', 'max','mean', 'median', 'std'])
means       = means.reset_index().pivot(index='supervised_model', columns='expl_framework', values='mean')
ax = sns.heatmap(means, annot=True, cmap="crest") #vmin=50, vmax=100) 
ax.set(xlabel="", ylabel='') #ylabel = metric_name)
ax.xaxis.tick_top()

# %% [markdown]
# ### 2.3.4 PGU

# %%
# Metric Per model/expl method
metric_name = 'pgu'
means       = results_df.groupby(['supervised_model', 'expl_framework'])[metric_name].agg(['mean'], axis=0).round(3) #min', 'max','mean', 'median', 'std'])
means       = means.reset_index().pivot(index='supervised_model', columns='expl_framework', values='mean')
ax = sns.heatmap(means, annot=True, cmap="crest") #vmin=50, vmax=100) 
ax.set(xlabel="", ylabel='') #ylabel = metric_name)
ax.xaxis.tick_top()

# %% [markdown]
# # 3 Individual sample analysis

# %%
# Columns to be used for analysis
cols  = ['supervised_model', 'expl_framework','selected_text','explanations_top_k', 'explanations','fa(k=4)', 'iou', 'pgi', 'pgu']

# Returns all elements of the df that share the same text and model
by_text                 = lambda df, cols, sample: df[(results_df['texts'] == sample.texts)][cols]
by_text_and_model       = lambda df, cols, sample: df[(results_df['texts'] == sample.texts) & (df['supervised_model'] == sample.supervised_model)][cols]
by_text_and_expl_method = lambda df, cols, sample: df[(results_df['texts'] == sample.texts) & (df['expl_framework']   == sample.expl_framework)][cols]

# %%
# Choosing a sample randomly for demo purposes
sample  = results_df[results_df['fa(k=4)'] > .95].iloc[16]
sample
# Out:
# gold_label                                                              negative
# texts                                              my nail broke  I haaaaaaaaate
# selected_text                                      my nail broke  I haaaaaaaaate
# supervised_model                 distilbert-base-uncased-finetuned-sst-2-english
# expl_framework                                                            random
# predicted_label                                                         negative
# predicted_score                                                       0.90889686
# explanations                   [(my, -0.9313673354456737), (nail, 0.515639108...
# fa(k=4)                                                                      1.0
# rank_correlation                                                             NaN
# iou                                                                          0.4
# pgi                                                                     0.003587
# pgu                                                                     0.102726
# len_selected_text                                                              5
# explanations_top_k_weighted    [(nail, 0.5156391082382206), (##aa, 0.59013385...
# explanations_top_k                                      [nail, ##aa, ##aa, ##aa]
# good_prediction                                                             True
# good_model                                                                  True
# Name: 10676, dtype: object

# %%
sample  = results_df[results_df.texts== 'im soo bored...im deffo missing my music channels'].iloc[16]

results_df[results_df.texts== 'im soo bored...im deffo missing my music channels']
# Out:
#      gold_label                                              texts  \
# 2806   negative  im soo bored...im deffo missing my music channels
# 2805   negative  im soo bored...im deffo missing my music channels
# 2804   negative  im soo bored...im deffo missing my music channels
# 2807   negative  im soo bored...im deffo missing my music channels
# 2784   negative  im soo bored...im deffo missing my music channels
# 2789   negative  im soo bored...im deffo missing my music channels
# 2799   negative  im soo bored...im deffo missing my music channels
# 2794   negative  im soo bored...im deffo missing my music channels
# 2790   negative  im soo bored...im deffo missing my music channels
# 2785   negative  im soo bored...im deffo missing my music channels
# 2800   negative  im soo bored...im deffo missing my music channels
# 2795   negative  im soo bored...im deffo missing my music channels
# 2796   negative  im soo bored...im deffo missing my music channels
# 2791   negative  im soo bored...im deffo missing my music channels
# 2786   negative  im soo bored...im deffo missing my music channels
# 2801   negative  im soo bored...im deffo missing my music channels
# 2803   negative  im soo bored...im deffo missing my music channels
# 2798   negative  im soo bored...im deffo missing my music channels
# 2788   negative  im soo bored...im deffo missing my music channels
# 2793   negative  im soo bored...im deffo missing my music channels
# 2787   negative  im soo bored...im deffo missing my music channels
# 2792   negative  im soo bored...im deffo missing my music channels
# 2797   negative  im soo bored...im deffo missing my music channels
# 2802   negative  im soo bored...im deffo missing my music channels
#
#      selected_text                                 supervised_model  \
# 2806       bored..    cardiffnlp/twitter-xlm-roberta-base-sentiment
# 2805       bored..        cardiffnlp/twitter-roberta-base-sentiment
# 2804       bored..  distilbert-base-uncased-finetuned-sst-2-english
# 2807       bored..  finiteautomata/bertweet-base-sentiment-analysis
# 2784       bored..  distilbert-base-uncased-finetuned-sst-2-english
# 2789       bored..        cardiffnlp/twitter-roberta-base-sentiment
# 2799       bored..  finiteautomata/bertweet-base-sentiment-analysis
# 2794       bored..    cardiffnlp/twitter-xlm-roberta-base-sentiment
# 2790       bored..        cardiffnlp/twitter-roberta-base-sentiment
# 2785       bored..  distilbert-base-uncased-finetuned-sst-2-english
# 2800       bored..  finiteautomata/bertweet-base-sentiment-analysis
# 2795       bored..    cardiffnlp/twitter-xlm-roberta-base-sentiment
# 2796       bored..    cardiffnlp/twitter-xlm-roberta-base-sentiment
# 2791       bored..        cardiffnlp/twitter-roberta-base-sentiment
# 2786       bored..  distilbert-base-uncased-finetuned-sst-2-english
# 2801       bored..  finiteautomata/bertweet-base-sentiment-analysis
# 2803       bored..  finiteautomata/bertweet-base-sentiment-analysis
# 2798       bored..    cardiffnlp/twitter-xlm-roberta-base-sentiment
# 2788       bored..  distilbert-base-uncased-finetuned-sst-2-english
# 2793       bored..        cardiffnlp/twitter-roberta-base-sentiment
# 2787       bored..  distilbert-base-uncased-finetuned-sst-2-english
# 2792       bored..        cardiffnlp/twitter-roberta-base-sentiment
# 2797       bored..    cardiffnlp/twitter-xlm-roberta-base-sentiment
# 2802       bored..  finiteautomata/bertweet-base-sentiment-analysis
#
#      expl_framework predicted_label predicted_score  \
# 2806         random        negative       0.8437804
# 2805         random        negative      0.88352424
# 2804         random        negative       0.9976128
# 2807         random            None       0.8514539
# 2784            dls        negative       0.9976128
# 2789            dls        negative      0.88352424
# 2799            dls            None       0.8514539
# 2794            dls        negative       0.8437804
# 2790            lga        negative      0.88352424
# 2785            lga        negative       0.9976128
# 2800            lga            None       0.8514539
# 2795            lga        negative       0.8437804
# 2796            lig        negative       0.8437804
# 2791            lig        negative      0.88352424
# 2786            lig        negative       0.9976128
# 2801            lig            None       0.8514539
# 2803      occlusion            None       0.8514539
# 2798      occlusion        negative       0.8437804
# 2788      occlusion        negative       0.9976128
# 2793      occlusion        negative      0.88352424
# 2787            svs        negative       0.9976128
# 2792            svs        negative      0.88352424
# 2797            svs        negative       0.8437804
# 2802            svs            None       0.8514539
#
#                                            explanations  fa(k=4)  \
# 2806  [(▁im, -0.9635555732321877), (▁soo, 0.11158799...     0.00
# 2805  [(im, -0.9635555732321877), (Ġso, 0.1115879988...     0.00
# 2804  [(im, -0.9635555732321877), (soo, 0.1115879988...     0.25
# 2807  [(im, -0.9635555732321877), (soo, 0.1115879988...     0.00
# 2784  [(im, -0.1612541), (soo, 0.047430098), (bored,...     0.25
# 2789  [(im, 0.0), (Ġso, -0.5628489), (o, -0.25202057...     0.00
# 2799  [(im, 0.0), (soo, -0.2879325), (bor@@, -0.6715...     0.00
# 2794  [(▁im, 0.0), (▁soo, 0.14163671), (▁bor, 0.2734...     0.00
# 2790  [(im, 0.6597536), (Ġso, 0.28230536), (o, 0.242...     0.00
# 2785  [(im, -0.23501037), (soo, 0.12778339), (bored,...     0.50
# 2800  [(im, 0.42653364), (soo, -0.22852504), (bor@@,...     0.00
# 2795  [(▁im, 0.19984944), (▁soo, 0.13323976), (▁bor,...     0.00
# 2796  [(▁im, 0.0), (▁soo, 0.07889231017432044), (▁bo...     0.50
# 2791  [(im, 0.0), (Ġso, 0.07967663472779342), (o, 0....     0.00
# 2786  [(im, -0.05712196290051501), (soo, 0.174205063...     0.00
# 2801  [(im, 0.0), (soo, -0.06959526220993832), (bor@...     0.00
# 2803  [(im, 0.0), (soo, -0.07321222), (bor@@, 0.3296...     0.00
# 2798  [(▁im, 0.0), (▁soo, 0.1638058), (▁bor, 0.16327...     0.00
# 2788  [(im, -0.06802127), (soo, 0.12832859), (bored,...     0.50
# 2793  [(im, 0.0), (Ġso, 0.17631528), (o, 0.245552), ...     0.00
# 2787  [(im, -0.1849099), (soo, 0.22583649), (bored, ...     0.00
# 2792  [(im, 0.0), (Ġso, 0.18023123), (o, 0.22409755)...     0.00
# 2797  [(▁im, 0.0), (▁soo, 0.13990779), (▁bor, -0.003...     0.00
# 2802  [(im, 0.0), (soo, 0.014712133), (bor@@, 0.2021...     0.25
#
#       rank_correlation       iou       pgi       pgu  len_selected_text  \
# 2806         -0.455842  0.000000  0.093408  0.001267                  3
# 2805         -0.341882  0.000000  0.597725  0.352700                  3
# 2804         -0.044544  0.166667  0.000032  0.000225                  3
# 2807         -0.400000  0.000000  0.050164  0.163586                  3
# 2784          0.044544  0.166667  0.003989  0.000127                  3
# 2789         -0.113961  0.000000  0.515559  0.744506                  3
# 2799         -0.500000  0.000000  0.167342  0.053931                  3
# 2794          0.000000  0.000000  0.078191  0.541395                  3
# 2790          0.341882  0.000000  0.665396  0.732312                  3
# 2785          0.267261  0.400000  0.003223  0.000219                  3
# 2800         -0.500000  0.000000  0.093510  0.063769                  3
# 2795          0.341882  0.000000  0.030300  0.095758                  3
# 2796          0.626783  0.333333  0.013330  0.437111                  3
# 2791         -0.113961  0.000000  0.574000  0.802832                  3
# 2786          0.089087  0.000000  0.000244  0.000100                  3
# 2801          0.300000  0.000000  0.029827  0.042367                  3
# 2803          0.500000  0.000000  0.043152  0.946987                  3
# 2798          0.056980  0.000000  0.085211  0.137377                  3
# 2788          0.178174  0.400000  0.000134  0.000113                  3
# 2793          0.227921  0.000000  0.776411  0.530154                  3
# 2787          0.311805  0.000000  0.000244  0.000346                  3
# 2792          0.056980  0.000000  0.484011  0.660904                  3
# 2797         -0.455842  0.000000  0.252146  0.060669                  3
# 2802          0.200000  0.142857  0.009628  0.945759                  3
#
#                             explanations_top_k_weighted  \
# 2806  [(▁de, 0.12395506204262818), (ffo, 0.156064936...
# 2805  [(Ġde, 0.12395506204262818), (ff, 0.1560649360...
# 2804  [(im, 0.12395506204262818), (def, 0.1560649360...
# 2807  [(deffo, 0.12395506204262818), (missing, 0.156...
# 2784  [(##fo, 0.106021926), (music, 0.13887194), (bo...
# 2789  [(o, 0.26199028), (Ġde, 0.26548672), (Ġmissing...
# 2799  [(im, 0.0), (ed.@@, 0.05315532), (..@@, 0.0557...
# 2794  [(▁soo, 0.14163671), (▁de, 0.15104836), (▁bor,...
# 2790  [(Ġde, 0.16908063), (o, 0.24241352), (Ġso, 0.2...
# 2785  [(., 0.14147504), (def, 0.1845306), (bored, 0....
# 2800  [(missing, -0.06453222), (channels, -0.0550970...
# 2795  [(▁im, 0.19984944), (im, 0.20643842), (▁missin...
# 2796  [(..., 0.21859450598771613), (▁de, 0.245889310...
# 2791  [(im, 0.1565563390404804), (Ġde, 0.16195296028...
# 2786  [(soo, 0.1742050632045451), (., 0.213486464935...
# 2801  [(im, 0.0), (bor@@, 0.010054101992676806), (de...
# 2803  [(soo, -0.07321222), (im, 0.0), (im, 0.0402207...
# 2798  [(▁my, 0.16152449), (s, 0.16322781), (▁bor, 0....
# 2788  [(music, 0.19117598), (., 0.29740247), (my, 0....
# 2793  [(Ġmy, 0.1925894), (Ġbored, 0.20000151), (o, 0...
# 2787  [(., 0.20473354), (soo, 0.22583649), (my, 0.28...
# 2792  [(Ġmy, 0.17303683), (Ġso, 0.18023123), (o, 0.2...
# 2797  [(▁music, 0.14694767), (▁channel, 0.2657875), ...
# 2802  [(bor@@, 0.20214997), (my, 0.27684924), (..@@,...
#
#                     explanations_top_k  good_prediction  good_model
# 2806            [▁de, ffo, ▁music, im]             True        True
# 2805                [Ġde, ff, Ġmy, im]             True        True
# 2804                  [im, def, my, .]             True        True
# 2807    [deffo, missing, channels, im]            False       False
# 2784          [##fo, music, bored, my]             True        True
# 2789           [o, Ġde, Ġmissing, ...]             True        True
# 2799             [im, ed.@@, ..@@, im]            False       False
# 2794             [▁soo, ▁de, ▁bor, im]             True        True
# 2790                 [Ġde, o, Ġso, im]             True        True
# 2785               [., def, bored, my]             True        True
# 2800    [missing, channels, ed.@@, im]            False       False
# 2795           [▁im, im, ▁missing, ed]             True        True
# 2796              [..., ▁de, ed, ▁bor]             True        True
# 2791               [im, Ġde, Ġmy, ...]             True        True
# 2786                   [soo, ., ., my]             True        True
# 2801         [im, bor@@, deffo, ed.@@]            False       False
# 2803              [soo, im, im, bor@@]            False       False
# 2798              [▁my, s, ▁bor, ▁soo]             True        True
# 2788                 [music, ., my, .]             True        True
# 2793             [Ġmy, Ġbored, o, ...]             True        True
# 2787                   [., soo, my, .]             True        True
# 2792                [Ġmy, Ġso, o, ...]             True        True
# 2797  [▁music, ▁channel, im, ▁missing]             True        True
# 2802          [bor@@, my, ..@@, ed.@@]            False       False

# %%
results_df[results_df.texts!=results_df.selected_text].texts.unique()
# Out:
# array(['Some goodies bagged at the car boot including some very cute cross stitch birds for my craft room! The man selling was a sweetie',
#        ' This was funny! I have 7.', ' rofl uh huh',
#        ' well doesn`t that look fab, even if I do say so myself!',
#        ' you`re so gorgeous!!',
#        '  Yeah I`m okay been icing and ace bandage and sitting on my **** on twitter... LOL Thanks',
#        ' I loved him and he was in a mini',
#        'Finally a chance to show genuine love, not dependent selfish love, I hope I can do it. My heart goes out to you and I`m sorry 4 ur pain.',
#        'Working up to my vacation to Thailand. Getting more excited every day',
#        ' good luck!! How exciting',
#        'Finally sunny days and I`m too sick to go outside and play.',
#        'Two months ago, I became irrelevant.',
#        'has a terrible headache.  I need relief!',
#        ' SherriEShepherd gave the link for  http://www.brentozar.com/twitter. He gives Twitter tips. Hope this helps',
#        'In the emergency room with my cousin. She`s got mad flu and can`t walk or breathe.  Why are hospitals always so cold?',
#        ' Have a great time in London',
#        'Good Morning! - Court - Crossfit - Bible Study - Someone very special`s house  http://tinyurl.com/cjs668',
#        '_ nooo  no roo crying. but omg i wanted to slap her. she was singing fine then from out of nowhere- BOOHOOOOOOOOOOO',
#        'busy working on a new kit... and a couple interviews done...Yea! The weekend! Pray for my Uncle, still young and had a massive stroke!!',
#        '_Kill_Boy oh sorry! not getting all my replies  nothing against you. and yes, i do know nirvana',
#        '  Thanks for the greeting',
#        'no phone call yet.. 20 minutes until I pluck up the courage. I WISH MY PHONE WOULD RING',
#        'Twitter, you just fail at life sometimes.  Oh well. http://tinyurl.com/qkxh7q',
#        ' ah, ok  thank youuuuuu!',
#        'jungle book 2 is sooooo cute.. i have nothing to eat or drink',
#        ' http://twitpic.com/4wb52 - Such a pretty baby!',
#        'Thanks to all my new followers!',
#        ' I`m game, too bad your leaving HI!',
#        ' i want to experience snow  we don`t have snow here and it sucks',
#        ' Thanks! Welcome back!',
#        ' NEW motorcycle and you POPPED a cable already? wow-you ride HARD!',
#        'Havin a much better day today!! Finished the last Twilight book yesterday. Classes start next week!      Get at me yall!!',
#        'am chillaxin after a busy BankHoliday, Hope everbody had a gd wkend! Holiday in 12 days!!!  ****',
#        'Oh, and yippee for Lyn-Z Way who gets to celebrate Mother`s Day for the first time as a mother.',
#        'i have such a sore head',
#        'Jon made one of the greatest dinners ever: roast pork tenderloin on a bed of wild rice on a bed of mixed greens & yummy sauce. No wine',
#        ' hahaha oh man please come to pomona i would love to see you everyday instead of like once a year if that',
#        ' I don`t think I am, my sisters refusn to get me a ticket now.  what you doing next week?',
#        'is bored, cant go on habbo stupid ban',
#        ' LMAO...Ha! No I just simply wanted to go to NY!',
#        ' Thanks Amy!  That video is so awesome!  Did you see TMH?  He`s amazing in that too!! Bouncy Bouncy Bouncy!!!',
#        'pacquiao fight was fun at home wif fam and melissa sat.    today was a mission to ikea. srsly 4 different freeways to ge to burbank.',
#        'i never knew a dentention was so hard 2 get',
#        'Why does #googledocs do folders, instead of labels like #gmail? I kind of like labels',
#        ' the exact one i was thinking of  the bestttt.',
#        'Just got an IM from another co-worker who just got laid off. Lots of people becoming unemployed',
#        'So screwed for sat 2 us',
#        'Cultural tour 102 by loiusa`s family: kangaroo sight-seeing in cemetary. Lovely',
#        'hates this weather',
#        '  Thanks! My mom`s seed is larger and already cracked (and planted). I hope Avalina isn`t a dud!',
#        ' How much longer is the NKOTB Block Party? Love it! I need to go to bed so just wondering what time it`s over..LOL..thanks!',
#        ' Dang... that IS disappointing',
#        'I`m sleepy but is feeling under the weather! ugh! These **** tonsils. I need some company or somebody to talk too!',
#        'watched 100th episode of numb3rs. loved how they did a throwback to the first episode, using the sprinkler theory',
#        ' either way, you always tend to make my #followfriday list, sweetie - you do rock that much',
#        'Ok that **** duet was hysterical LOL',
#        ' Hello Gorgeous GIRL! Nice new pic!  HOw are you today',
#        '_ranjan Did I ever mention what a nice and awesome dude you are?',
#        '_Ichigo She tried to carry on aswell, bless, I suppose maybe that`s why kids shouldn`t be in it?',
#        'is anyone out there??  so bored at work...',
#        ' Ok then have a good day',
#        'planning! and trying to call the doctor, though that isn`t going so well. So mostly, planning',
#        'Counting the hours of lost sunshine until the Weekend',
#        'booziest weekend in a long time, good fun though!',
#        'working on diffusing that irritation but this traffic sure isn`t helping  mother F! it`s always real bad the days th@ i help plan stuff',
#        'DH is just about finished making his giant Trio candy bar. Thank the heavens. His work mates are in for a treat tomorrow!',
#        ' So!!! Why should that matter? I bet you would be GREAT at it! I do!!! It`s what you love, right? Why not go for it!',
#        'Just got back from working out. I`m feeling pretty good. work at 4:30',
#        ' did you see the 15 sec clip of the New Moon trailer?? its up on ETonline.com ...check it out. its a big tease, though',
#        ' Discrimination is not a bad thing. I`ve learned to say no. My children would say I mastered that years ago',
#        'just came back from karaoke & eating dinner with emily. it was sooooo much fun',
#        ' I submitted my resume the same day and saw no answer back. Oh well...',
#        ' .. .great.. you can buy me lunch when i get my 10-15% pay cut next month..',
#        'missed out on westcott micro apollo too',
#        ' boo... i was hoping for a fake alien story with a tinfoil covered beachball photo',
#        'Sooo.....I`m kinda o sick n tired of the bs that guys dish out  !!!!!!!!',
#        'I love when ryans a housewife. Makes me smile.',
#        'Am hating my life at the moment. There`s only so many NOs my delicate little mind can take',
#        'Gotta get creative with these mothers day gifts. I`m gonna win them over with my love!!',
#        ' nice one !',
#        " ...i`m sorry about you are still sick  u know most of them, AND i know that u will guess the 'pelzer present' ;-)",
#        'What am I doing atm? http://twitpic.com/4jmeh Oh yeah. Apple Juice  I`m such a rebel!',
#        ' wheres the music mannnn!!?? my inbox is still empty',
#        'Is happy...Skool just let out..! Today was my last day..! Yippee! R.I.P Jackson Tyler Morris..! Always Loved And Never Forgotten..!',
#        '_kap But I think it`s cute.  Do this every night okay?',
#        ' aah. well, have a few friends over there. Just wondering if all`s great and weather`s been good...',
#        ' Already got my ticket; thanks for making sure though!',
#        'Crisis: forgot my fringe comb  I`m with men....no one will help me',
#        '_xo they were so pretty and took like an hour to do  CAN I DO URSSSSS!',
#        '  That was stone cold   Crazy....  ?',
#        'I lost my artistic abilities',
#        ' lol hi emmy, latin would help me study for the aptitude tests to get into grad school ;\\ thats why i wanna take it',
#        ' Not available in my area  I would too',
#        '_michele thanks for that...am now following them...love good causes',
#        'sorry to tweet about BGT but poor wonderful crazy weird Greg  so not fair. the silly little girl is never going to cope. urgh. NOT FAIR.',
#        'says Happy Mother`s Day to all Moms out there  http://plurk.com/p/stkr2',
#        'first day of summer sucks!!!! its overcast and cold...  this isn`t summer!?!?!?!?',
#        'Waiting for 5:00 & having cramps',
#        'just when i thought things couldn`t get any worse. it just did. and it will get even worse tonight, i bet.  my life is a misery.',
#        'Wide awake and grouchy as ****.',
#        ' lol i know but it was just so funny, ahaha',
#        '1st presentation for senior boards? FML',
#        'philosophy final today! thank you  it`s 3 days now!!!!',
#        'nooooo its raining......had 2 leave the beach',
#        'Great weekend, even though my site is not moved. Plenty other things to do and learn. Keeping the faith and looking to the future',
#        ' very very cute  and fun to watch.',
#        'i just bit my tongue.  blood everywhere!!!',
#        '__buckley Good for you mate, sadly I couldnt get pissed tonight **** driving bad times',
#        ' sorry we didn`t get a chance to chat at #screengrab09. Caught glimpse of you across room but was dragged home prematurely',
#        'Just lost my internet signal  how will life go on',
#        'Omg, my mom just called... Im too late... Hes gone',
#        ' don`t know it really hurt my arm. guess you have to booze me.. or just ask  or  if you don`t believe me!',
#        ' I know, that is so sad.  I',
#        '; keeps getting such delayed responses. why is my internet so messed up?!',
#        ' thats what doting husbands are for LOL!!  I hope that once my braces go on, I can eat normally again',
#        'tiiiiiiired! Going to bed! Drinking leads to making out with boys, who you later forget their names.... Don`t drink kids. Goodnight',
#        'Not going to the dance recital and now i feel like a piece of **** cuz it cost so much money',
#        'okay okay sleep for realz now! Goodnight!  ::waves to followers::',
#        ' You know, your updates are really amusing.  How was the prop auction?How much did that baseship bed go for?',
#        'I have to reupload the **** thing again',
#        'i jus love doin night shifts...will be done in an hour',
#        'My poor heather, she didnt make the cheerleading squad. Im sorry babygirl. Maybe next year',
#        'I can`t believe I thought I had a morning shift today and told Alex that I could take him to the airport.  His flight is during my shift!',
#        'Just came back from watching Terminator Salvation @ Cathay. It`s so-so only, not so much action  but I feel sorry for Marcus though.',
#        'Loves the fact that there`s only 5 days of school left',
#        'Good Morning Twits!  Let`s makes today x100 better than the one before! Start runnin',
#        'Uber Bored ATM, after Out of the Blue, will have shower, then watch house or numb3rs (vid) then CSI + CSI NY + Bones Double . .. . YAY!',
#        ' Aww, congrats to the family. ;) Send me piccies in the email!',
#        '_beery Yeah little rough this morning but more tonight, and tomorrow night if all goes as planned. Caloric intake off the charts',
#        ' awesome..am headin there that nite after my grad dinner  c u then boi! hehe',
#        ' Oh no!! I hope it`s not bad',
#        ' ahaha its stuck in my head; thanxx',
#        '_ Oh god, yeah! I forgot about that',
#        'What did I learn today? Never post anything you`ve sold on ebay using royal mail. They lose it, I refund: compo`s nowhere near - my bad',
#        'I`m poorly and can`t sleep',
#        'Wishing all the mommies out there a very happy day!!!',
#        'Enjoying Mother`s Day', 'Happy Mother`s Day to all the mommies',
#        '_babe woo! im getting mine on monday,cant wait  x',
#        ' SHUT YOUR FACE! Why are you so mean to me? Pedro is supposed to be the mean one',
#        ' http://twitpic.com/4qpzx - i love you guys  you`re the best',
#        'I hope everyone had a great weekend! I will be here on and off today as I have 2 important meetings today',
#        'Buried under more web changes. Going to make lunch now... I won`t have a chance later. Too much to do.',
#        "Happy Star Wars Day ...  'May the 4th be with you'.... read http://tinyurl.com/axsujx for more ;)",
#        ' nice clutch', 'Star trek was good times.',
#        ' Every time I have Friday off. Sadly, that`s not too often',
#        'and thanks,  , fr. yr congratulatory gweetin`',
#        'This is my favourite shirt, because its true.  <3 grumpy.    a) cute  b) huggable  c) life of the party  (d)... http://tinyurl.com/q7eax7',
#        '_Craig_G Hope your enjoying the money..it`s looking real good to me right now',
#        ' Thanks man.  That sorted it. I only ever remember 222.222',
#        'has broken off the fb wedding so sadly no longer has an excuse to get @ hauntingxealot to Goulburn',
#        ' Do a tour in the Philippines sometime.  A lot of fans here would really love that!',
#        'HA. Totally posting an update at 2am.Its lightning outside, pretty.',
#        'Invisible car helps to boost recycling. Honest   http://twurl.nl/fdgmyo',
#        '...  that was meeeaaannn. people make mistakes ok?! lol',
#        'can`t wait to november for Jobros concert ! In examination',
#        '_Lay aww well I just randomly woke up and now I can`t sleep! Too many things on my mind',
#        '****, I never knew I could miss my phone so much for 4 hours till they told me I won`t have it back till then',
#        ' haha best thing about office birthdays hey',
#        '_KittyKat hello new follower  haha!! how are ya?',
#        ' seems to have disappeared out of my life',
#        'That`s it? It`s done already? This is one proof that there`s nothing fair in this world.   http://bit.ly/10UEMq',
#        'I`m trying to find the driver for my Microsoft Lifecam VX-3000 Webcam and can`t find it anywhere! anyone have any links?',
#        ' how sad! are you saying that I`m fat?  *tears*',
#        '  Hi, Thx for following  I teach some Chinese lessons on youtube, pls feel free to have a look www.youtube.com/ChineseLearn',
#        'Ugh! I wanna play dnd but i know i`m going to fail this final. I NEED to study',
#        '_3 U know - kids do what we DO - not what we SAY ... well, don`t we all, really  ....',
#        'I just spent 2 hours looking for a blog topic and ended up inventing my own.  grrrr    http://bit.ly/QRz6y',
#        '_dulay i swear it took me 2 hours to get from bel air to alabang.  but yes, i LOVED reminiscing about our HK trip with you & ',
#        'Goodmorning twitter, oh my gosh, i woke up soooo nice, lol ... oh hai thar twitterverse. Happy #mothersday everybody  (especially mine)',
#        ' great pics! You should try to start selling your race photos to runners',
#        'Rockstar photographer shoot went great tonight. A little different than the usual stuff - very nice.',
#        'Shower. Class. More class. Taking care of my lady-friend. Writing like there`s no tomorrow.',
#        'i have no idea what im doing and i am completely lost.',
#        'OH NEVERMIND I THINK THIS THING IS UNSALVAGEABLE',
#        'this day has beasted me.',
#        ' I think that may look a little silly -.- Also my camera is broken so no photo',
#        ' awww hes too cute!!wish i could`ve gone',
#        'Finally get to lay down for a bit i have a major headache',
#        "watching 'That Thing You Do' on Comcast. Missing my boo like crrrrrazy!",
#        'So glad I`m finally done with finals!',
#        ' I`ve read good things bout it. Just not feelin it tonight. Proly finish it tomorrow, after Star Trek',
#        'Good morning  ready to start this week.',
#        'GOODNIGHT MAGIC AND PRETTY WORLD',
#        'The usual. Two family parties today. Happy Birthday Lily!  http://twitpic.com/4w472',
#        'It just had to rain on me almost a perfect day now my clothes are wet',
#        ' ugggh idk how to do that  but i only wanna stop getting texts from twitterr  -ilsE*',
#        'Just got confirmed that itï¿½s pizza-time with some ex co-workers on friday...looking forward to it',
#        'i would slip and fall... on the dirty school bathroom floor. fml.',
#        ' lol, i`ve done that one b4  i`m a victim 2 that! lol',
#        ' I miss u guys too  I prob won`t b bk til august sumtime... But if I come bk anytime b4 then ill 4 sure let u kno!',
#        'So tired & ready for bed!! Really in the mood for salt & pepper chicken wings & noodles but have no money on me for a Chinese!',
#        'Writing my Music Lit final paper on Mozart`s Eine kleine nashtmusik. Mom is giving me a hand...and I`m actually having a GREAT time',
#        ' yessir that is 100% right',
#        ' very relaxing thank you. Hope you get to put your feet up tomorrow and enjoy the day',
#        'Stupid me, accidentally gave my honey the Atomic flavored buffalo wings and now his stomach feels just awful..... Im sorry baby',
#        '  Yes, you should go see Star Trek!  It`s sooooo much fun!',
#        'i got over the crush issue but now tomorrow my friend is going to india for the whole summer  im back to being sad.',
#        'Going to the courthouse to pay for tags & taxes on all our cars...this is gonna be expensive.',
#        ' COOOOOOOOOL... DOOOOOOOOOWN... Patience... Is... Virtue...',
#        'has just finished ironing his clothes for #Church. Gonna walk the dog now then grab a shower/shave and be off  #jottonia looks good too',
#        'I think I may have ruined a friendship this week by getting carried away',
#        ' aww thanx andy',
#        ' Unfortunately for us it looks like there are NO funny people on twitter  Should we move to FB or start our own...flitter',
#        ' I feel your pain. Mine is the same way',
#        ' l`m on 3 days too matt. No fun this weekend.',
#        ' haha im jewish, i love that one',
#        'Please Review Sunehre Ad Placement  http://tinyurl.com/oow6mk',
#        ' Sadly no. It didn`t come with one...',
#        ' I`m 25 in december that`s not good at all next big birthday is 30  after 21 it flys by for sure',
#        '_30439 I really wish I could go!',
#        'Version 2 of our live, interactive Trans-Siberian ticket planner is launched: http://tinyurl.com/c5ljwm - its very cool',
#        ' aww I miss driving down elmwood',
#        'Cant wait to see my boy tomorrow',
#        'is spending her Saturday morning taking notes for a research essay because some stupid **** recalled the book I`m using. Not fair',
#        '_2nd aww thanks!',
#        '90 degrees, gross skies, and thunderstorms...perfect match for my mood  lol',
#        ' I only do computers. Am hopeless at everything else',
#        ' i agree with you!',
#        'Gonna celebrate Mothers Day with the family but gonna start the partying tonite',
#        ' oh nice going!',
#        'Ok so I`ve now got a bit of a bad back after lifting all drum hardware into my car   downer.',
#        ' Sorry RB is on PS3 for me', 'this is sooo crazy i have fever..',
#        ' Damnit all. That sucks.  You were one of the ones I thought I`d drag back lol',
#        ' ohoh i missed all ur tweets  im gonna have to stay awake all night to see the announcement now, **** time difference',
#        'dang last url went down  ? http://blip.fm/~7aigm',
#        'I just stuck my finger down my throat and there are a bunch of bumps on my tongue & throat.',
#        '  This has made my night!!  Way too funny!!',
#        'tamlyn wishes she was as cool as my sock draw',
#        'I have such fantastic friends, including several ones met through here! thanks for being in my life - you are such amazing people!',
#        'My phone passed away yesterday.. He jumped off the table  Searching for a new phone...',
#        ' it means that you are now FAMOUS. Congrats!',
#        'I sure do hope it becomes 4:20 this afternoon ...',
#        '_x_ATL u mean jack barakat`s?! wow so have u ever gone to his house? Hehe i mean ur ssoo lucky to have the address!',
#        'Yes, I love tea. If that makes me typically English then so be it',
#        ' Yay, three followers! Good to know more than one person in this big wide world likes fishies.',
#        'both electronic keys stopped working. there is no keyhole! cant get in my car. so much for technology',
#        'I`m so hunrgy right now and these heels kill me I can hardly walk in them',
#        ' Si, no bueno  I guess I just don`t entertain him :/',
#        ' pancakes!! with lemon and sugar thanks!', ' a mouth for sure',
#        'Daniel has won DSDS. His voice is great.', 'I hate the dentist',
#        'Laying ALONE!! Since Mook`s soo comfy in his f`n play pen. I thought it was ill at first now I don`t have no one to cuddle with...',
#        ' sorry  friends - I`m swamped with deadlines right now and we have family visiting to boot! No charades for me.',
#        ' Thanks for the warm welcome! We didn`t make plans   because our arrival time was so up in the air.',
#        'Woo CAVS.  Happy Mother`s Day!',
#        ' nothing aimed at you, just joining in...sorry',
#        'Dosen`t Want To Go To Work Tomorrow',
#        ' yep infact she is popular, miss india 99, talented film actress .... and lot more',
#        ' Have a good one', 'I wish I could get my nails done  stupid job',
#        'I`m taking a twitter break. Cell is dying',
#        ' I am lost. Please help me find a good home.',
#        'Felt like ****, behaved like my son; ate to compensate. Pigged out on home-roasted sugar almonds. Painful tum, threw up, still feel sick.',
#        'I am tres depressed', ' I`m sorry to hear that.',
#        'Getting ready for week  Its too nice today to be stuck inside working!',
#        '  Thanks',
#        ' *laughs* I`m glad that you have self confidence - it`s a wonderful trait to have  I`ll applaud extra loud for it, okay?',
#        'Watching Ellen Love her!! then doing the dishes  and tanning ...it`s gorgeous out!',
#        ' Yep, finished, chocked full of spelling and grammatical errors, but I`m cleaning it up tomorrow and popping it up  hehe',
#        'Going to miss my roomie ... We will no longer be roomies starting tomorrow',
#        ' it makes me happy to hear a girl talk, or tweet, about the nba. but... could you give my nuggets some love?!',
#        ' That`s awesome dude, yay for surprise celebrities!  I got to meet him a few years ago, he was soooo friendly.',
#        'HAPPY MOTHERS DAY.!',
#        'writing report cards  soooo tired but what an amazing day. check it out on fb soon!',
#        ' Yes it does. Please dont` go. If you die I will cry.. which normally leads to small animals getting harmed',
#        'discovered cause of a bug in the new #NetPLAYER 4 build. Publishing bug fix now, hopefully new beta by tomorrow',
#        'Trying to decide on a movie with the friends.. not going to well! lol :p  No bible study 2nite, which means ****-day cake  buy my own??',
#        'almost died. Laptop screen was set to 100% brightness after I reinstalled Windows Vista. Got a headache now  #insanedefaults',
#        'FTSK and Mercy Mercedes were amazing tonight.. as always',
#        'thank you for teaching me values and to be a better person each day  I LOVE SO MUCH, YOU`RE THE BEST MUM IN THE WORLD',
#        ' Happy b-day! Just woke up on this side of Earth, so wishes are bit late',
#        'Went to a party last night. Dindin and I showed up in matching outfits ) GREAT MINDS THINK ALIKE ) Anyway, happy birthday, ate lara',
#        'can`t school just be done already? it hurts too much... seeing him every day',
#        '  hope he is ok!', ' what`s goin on hun?  I`m worried about you',
#        '2 days without sleep and now a migraine. I thought life postR01 was meant to be relaxing',
#        'mcfly gig last nightt omg it was amazin didnt sit down through the whole thing  mcfly did you see me and ma best mate we were in tutus',
#        ' u think u have bills Ha!Ii just finished paying mine that`s y I`m broke',
#        'ohh my tooth is hurts ohh  im sad it very hurts',
#        ' doing pretty well, up and wide awake',
#        'seriously bored without anyone to talk to... but not tired enough for sleep',
#        'Argh noo! Missed The Killers on Wossy!  That sucks! Missed out on Brandon. Total failure! Anyone know if it`s repeated? Must investigate!',
#        'My frist post... Off to find a new car for my parents, exciting!',
#        'My dog is officially depressed that my brother`s dogs are gone. He doesn`t want to go outside and when we did, he play half-heartedly.',
#        ' Sorry to hear ur flight got cancelled  that blows!!!',
#        ' I know   It was worth a shot, though!',
#        'Dinner with the fam... I have missed them',
#        ' _ i am glad to break my twitter virginity with you two.',
#        ' I saw the play of it here, it was amazing',
#        ' Im not bannished... but I am at work till 6',
#        'Just opened a facebook account, I`m a little confused I don`t really get it. Twitter seems much better',
#        'today is a busy day. exhausting!',
#        'Laying in bed til workkk... Oh the life. Definitely pinched a nerve.',
#        ' Not going to dwell on it. It happened, it`s passed. Just a shame as he was so supportive! Such is life!  x',
#        'DUSTBIN BABY ON AT 11.30 Cannot wait  x',
#        "'my name is Tony!!!!!! ...not hey!!!!' -  poor tony",
#        ' Beto`s Pizzeria is on Banksville Rd in I believe the Beachview area... Sorry to answer like 100 years later',
#        'today was a lovely day! I had fun with  and  this evening!',
#        ' WE Quite Like Worthing its a relaxing place with nice coffee shops and fresh air.. and not too many Oiks',
#        'sigh, my sisters bein strange.. she came all the way from copenhagen to london, and now her phones turned off.. i wanna see her dammit',
#        ' AWWWW  we`re gonna miss you!', 'i am living in ignorance  :@',
#        ' I feel for you  I hope it`s a smooth flight. Be safe! Mucho amor from Boston!',
#        ' So sorry to hear about your mom! that really sucks',
#        'Aw, not going to Toronto anymore.',
#        'I`m sick and sad .... missing out on Martini Lounge tonight',
#        ' it was amazing',
#        'Garden going well, almost all the corn and peas are up, no onions or beets up yet though.',
#        '_Libertine um, glad you enjoyed it...',
#        " 'organization ...ITIL, forget about people (and so they fail)' preaching to the converted  IT is the people http://tr.im/kWUA",
#        ' traumatizing moment of my childhood. my dogs massacred baby bunnies and my brother and i got out the bb gun...',
#        'had a good day driving up mountains, visiting katie, eating chips & fudge and stocking up on lovely smelling soaps',
#        ' Thanks for the support',
#        ' im allergic to cats! my tonsils get swollen and they hurt  what do i dooo?!',
#        ' you should say mlia instead of fml  i hope you find it soon',
#        ' Thanks for sharing that',
#        ' sounds like you all had a great night . i`m glad it was successful',
#        'I miss her alot and its only been one day',
#        ' He says he feels mama tucking him in at night  He`s lonely but getting by. Tomorrow will be tough!',
#        'Hates headaches! Maybe I`m not ready to rock',
#        'Can`t sleep...so I`m watching HGTV. I`m afraid infomercials are about to take over',
#        ' I bet its cool down in SR, huh? It`s not here. I haven`t stopped sweating since noon when dad and I were packing',
#        '_a_michael Hey! thanks for another great day! I`m going to sleep now! I`ll chat with you tomorrow!  Sweet dreams!',
#        'sorry guys i didn`t sign in for a while  sorry every1',
#        '.....headache',
#        ' http://twitpic.com/4v0vr - cool! you and your mother have awesome hair styles,! Wish her a happy mother`s day!',
#        'I missed your calls',
#        ' thats pretty bad quality and probably the worst pic u posted till date',
#        ' I didn`t want to tell you but I think it`s your body odour',
#        'Stupid bipolar weather ruined my day off',
#        'happy mother`s day mothers.',
#        'I don`t think I`ve ever been so tierd in my life.Ugh,goodnight.So sleeping in tomorrow',
#        'Stupid jobs, idk what to do.',
#        ' haha thanks  its for history and its on how the invention of television has influence america lol',
#        'IN PAIN. my big toe got stomped on during the hokey cokeu. it`s throbbing. anyone have any suggestions to heal it?',
#        ' sweet dreams',
#        'I`m getting me & my family ready for Kaylee`s graduation! It`s gonna make me so sad.',
#        ' Like your pics, Lucky Girl, again',
#        'We are on the slowest train ever, it stops everywhere. Missed a quick train by a few minutes',
#        'And the Sun is shinning.........at last',
#        '_rc234 haha  yup. but still have a terrible headache and super swollen and puffy eyes! i dont think im going out today.ugh!',
#        'i have such a hard time talking to new people -  I am pretty sure I didn`t make a good impression.....',
#        'Feeling loved!  My Mom got me a Nikon Cool Pix for my birthday!!!!',
#        'this week of mine was not easy!  but finally it`s over! (:',
#        'NOW IM SAD BUT IM NOT GIVING IN FIRST..I DIDNT DO NOTHING!!!!    :**-(',
#        'http://twitpic.com/67qv3 - Me at Forever 21  Ethan couldn`t be there',
#        ' Still jealous', ' lol. just don`t ever forget me',
#        ' lol dammit  well then next time then',
#        'Is heading home from foot surgery and wishing she had a boyfriend to come over and cuddle with',
#        '   Wow what a beautiful picture... and by the way....I am straight....just wanted to let you know!!!     Bella',
#        'Off to Woolsery this morning to (hopefully) see North Molton U16 clinch the North Devon League title. Lovely day for it',
#        'cooking with my dad  having lots of fun in the kitchen together',
#        ' you know you want to come keep me company whilst mum`s at her friends for the night  it`s such a nice evening!',
#        'In Arch. Drawing. Checking out MVCC`s CAD degree. Looks good to me',
#        'I don`t want to sit at home on prom night. Someone hang out with me',
#        'No waterfront anymore   faccia luna and clarendon will have to do',
#        'http://twitpic.com/4wukt - We bought Ludi her own rug. Dogs are the best',
#        ' I love mine, too . happy motherï¿½s day to your mom , John Taylor  . much love to you, too .',
#        'Took a shift tomorrow.    I don`t really feel like working right now.',
#        ' Now you only have 2 hours to sleep...  - Rest if you need it.',
#        'Ok ... the passengers ... no one is alive ... they`re all dead ... you just don`t know it til the end ... then you cry ...',
#        'i have an urge to play wow but i have to wait 2 weeks til im at my dads! 5+47DAYS TIL MCFLY, im so excited  (L)',
#        'Slipped up and caught the flu  feeling like poop!',
#        'According to , a quarter of families under six live in poverty.',
#        '   Sorry, we`ll try to keep it down.',
#        ' No it`s not sad. Should make you proud',
#        ' And most of us are going to be stuck in an office, some without windows',
#        'Home until tomorrow. Did my running and spinning. Now time for chiropractor, laundry, shopping, and visiting family. Missing nathan',
#        'gettn ready to take a trip to Jersey my dad`s not doing so good, he needs a new heart~whoeva see`s this please say a prayer for my dad',
#        'Hicks are mean!', 'the plan to not spend money is not going well',
#        ' but it all went too quick and there wasn`t a chance lol',
#        'workin a long day today... hopefully i can make some good tips',
#        ' but my bday is JUNE 19.. this is wack... and ihavent seen any promotions for my bday party  someone better finagle this asap!',
#        ' actually, I wish I was back in Tahoe.  I miss it there.',
#        ' congratulations ! you guys finish a month early than we do. booo',
#        'I`m missing crab legs and attending my going away instead!',
#        'My Street Fighter IV skills are lacking, can`t beat Seth on easy.',
#        '250 miles down, only 1750 to go. Thats ok, u2 on the radio alwas helps.',
#        'The birds are out,, oh man... That`s NOT cool && I didn`t sleep yet for the night!!!',
#        'Just woke up :o mums singing to her new gn`r cd replacement i bought because im a good daughter',
#        ' That`s just weird... :\\  Oh, and what was it you were drawing for me?',
#        '  you`re missing out, bb! i`m such a cereal nut, i think i like every kind available.',
#        ' FIL 461 with cool people like me',
#        'Here`s a brief preview: http://bit.ly/eHCfP   OMG James is creepy in that role! I`m scared of him',
#        'Why kiss the feet of the people who kick you when you can be anything that you want to?  morning everyone! Hope you have the best day ever',
#        'Bumping dj opus in the drunk in the car.  lmao. Don`t act like u don`t know.',
#        'my son got stung by a bug for the first time  his little finger is slightly swollen.',
#        'Good Morning!!! Work and then it`s ESPN`s Sunday night Baseball. hopefully it won`t get rained out',
#        'Wolverine Was BOSS! Seriously, And Will.I.Am Was In It, What The **** ??',
#        ' awww she`s laavly ;) I had to come in  but I`ve got a stunning wee tan (l) ;) yourself?',
#        '  Cool...a VERY productive day! I just got a spot as an extra in a feature film that is filming tomorrow  AWESOME week all around!',
#        'am bored out of my skull.  i have got to get a job.  this SUCKS.  i need entertainment. /grumbles',
#        'Just drove by fisher and I feel so sad',
#        ' cheers for the aptism link',
#        ' Thanks, I just found a article that say i cannot join you because i am in the UK though',
#        'Boring starting work weekend soon................ 1st need to get a Tim Coffee so I can make it through this **** night shift........',
#        '_Dew tokens haven`t been working for me all day....',
#        '_Janeway OOC: Goodnight',
#        'I wish I knew how to play an instrument. Lessons for Menace and Missy Moo, for sure. Piano? Cello? Bass? Whatever they want',
#        'This is what I had to endure to get prizes of to my lucky winners  http://twitpic.com/669nm',
#        'Epicfail and Joseph in class... Very long liao',
#        "Actual wiki entry 'The Million Dollar Homepage' made me just shake my head due to the fact that ... sometimes...somtimes things just work",
#        ' Whom do yu wanna kill ??',
#        ' and I`m really glad you were able to watch the game',
#        ' her son is 7 and captured it outside...THANK GOD I HAVE A LITTLE GIRL',
#        'watching Bones with Naty. Have made her a fan! Mission convert Naty: Success...now onto Mission convert Meagan',
#        'and we`re off  to OT !! exciting game like always', ' Thanks',
#        'facebook quizzes are one cure of boredom haha, my teeth/mouth hurts',
#        ' lol! Ahhh well its a good song',
#        ' Bye ! Have a great time being whisked away',
#        'Sob! I can`t believe I`m ending my work week at the chapter about what Augusten Burrough`s father did to Ernie the guinea pig!',
#        '_13 Awe, THX so much! Neither of need 2b sick on Friday!!  Do u have any prayer requests?',
#        'I dont like seeing my best friend cry, it breaks my heart and I dont know what to do or say',
#        'Nic has no idea what he`s going to do!  money is all gone!',
#        ' Happy Mother`s Day!',
#        ' ugh! **** it. Today doesn`t look like it`s going to work  i`m sorry',
#        '@_Glitter_  kk but 4 sum reason its not lettin me vote 4 them',
#        'I ate to much lunch...now I don`t want to work',
#        'I think my cheap sunglasses are falling apart. Oh well',
#        'drinking some really nice coffee, got to go to the dentist at 9am this morning',
#        'Weekends are Great....if you don`t have to work them.',
#        '_Divine take my advice lookin through the phone cost me my relationship',
#        'I had some work to do, but my wrist hurts too much to do any of it.',
#        '****, got Chili Beans on my shirt  I hate that I can be a messy eater. Such a lady!',
#        ' morning Alex hope you will be tweeting lots today as we do miss you when you aren`t on here  ****',
#        'thanks for the raspberry-Laced Vanilla Cake',
#        'Suddenly I remember all the memories with him  ohhh please',
#        'Omg going to die of swine flu when I go to Melbourne',
#        'Unanticipated thunderstorm quashed camping trip',
#        ' Enjoy the ride', ' TY very much for FF',
#        ' I thought it was pretty good! I`m not a die hard Trekkie either.',
#        ' heeeey good luck for unair sweet!',
#        'Rescued two adorable pit mix pups today.  LC and Brody.  Looking to adopt?  E-mail me for more info and pics!',
#        ' oh ok. Well good for you...can I get some weather updates instead??  jk.',
#        'life`s good',
#        '_Twitster ohhhh, I love Morse, have every episode on video & sometimes gaze lovingly at them',
#        'just come in from the garden. It is very warm out there but beautiful. Didnt do much revision though',
#        ' mmmm lauren conrad eeeeep im going to miss the hills',
#        'Enjoying a beautiful day off by hanging around the house. Pam is making a cake, but she won`t give me any',
#        'Taking 40 underpriveledged kids to the circus 2moro. BIG day planned & I still aint feeling 100%  so nervous right now..',
#        'I`m SO thinking about skippin out to NY in the morning. . . but all of my plans were for tonight  well . . . most of them anyway.',
#        'ShoesShoesShoes.YayYayYay.lol.IWouldPostATwitPic.ButIdntKnoHow2',
#        ' it was a biligual sweatshop LOL I talk 2 him once in a while but not as much, he got an r6',
#        ' you could say that. I left it in VT and have been Blackberryless since Tuesday Night. I`m lost',
#        ' - Bless you as well sweetie, and i hope you have a wonderful weekend',
#        '  it might be the swine flu! haha `cause i`ve got the flu',
#        'I think I should hire one of those tranlsators.. because no one ever understands me....',
#        'Going to the Star Trek premier tomorrow night, uber stoked. I don`t care if I`m a nerd, Star Trek is amazecore!!',
#        ' Heavens, not good  I can empathise. Fingers crossed it doesn`t come to anything and you can sleep easy. Wishing for the best...',
#        'i can`t studyyyyyyyyyyyyyyyyyyyyyyyyy  i have an exam tom',
#        'Happy Mothers day to all mums', 'live long and prosper',
#        'always excited for a new chapter in my life. just didnt expect it to be so emotional.',
#        ' hahahaha wtf dianne????? who twitters that lol...i guess it depends who the person is.....',
#        'is going to watch the two davids. yey',
#        'has two tickets to Amadou and Miriam for Tue. June 2 that I can`t use  $25 each to anyone who wants `em. That`s face value. Should be good',
#        ' Nice! You should submit that to failblog.org',
#        ' Hey im a fan from New Zealand. Loving the show even tho we are soooo behind in the episodes! haha. Keep up the good work',
#        'in about half a hour i`m going to my english lesson...guess i`ll have to wait...and wait for a couple hours so i`m over with it.(( :S   ))',
#        ' You win ... SIGH Rakeem',
#        'acsvxdcbgfn soccer now. shall see young phoebe after D: I don`t want her dressed up though',
#        '  great pic,have to upload my pix tomo,I`ve no laptop tonight.',
#        ' hahahaha. im listening to my iTunes library, a bit of Sonia Dada atm,  ITs good',
#        ' hell yeah! Belgian beer is the bomb!!  :p',
#        '  ROFLMAO for the funny web portal  =D',
#        ' I always feel guilty about it',
#        '  that would mean me babe! but **** it my name  is SUPER FREAKIN COOL! I give myself a pass! HA!',
#        ' The episode was AMAZING...I cried when I saw the home videos they were soooooo cute',
#        'has burnt my hand on the cooker, it hurts',
#        'sooo glad im home  floridia was fun!! back in ATL. time to sleep....then back up to work!!! constant grind.',
#        ' Miley, I tried voting for you, and it wont let me vote for some reason  Ill try back a little later! <3',
#        'She doesn`t believe spending many (many) thousands on a perfect wedding makes a happy couple.....A happy couple makes a perfect wedding',
#        ' ugh I`m not doin too good',
#        'net .. net .. net ..  hmm. bad weather .. weird summer!',
#        'Its 11:11...make a wish!',
#        ' hey i loved ACS but i had to see it online, is not here yet   cant wait to buy it!!! you look amazing there',
#        ' hope ya sleepin well  guys still here',
#        'Rats the Creative VADO`s are out of stock at walmart.com I`m too late.',
#        '4 more followers.. follow me and I`ll love you!! *pouts* Please?',
#        'its so nice.. I LUV KELLY...she`s such an amazing singer  LUV HER',
#        'happy star wars dayyyy =D and hbd to uncle LEE',
#        ' Thanks G! My actual birthday is on Tuesday and I will be 24.',
#        ' I wasn`t feeling it', 'Happy Mothers Day!!!  <3',
#        ' Just saw you on TV for the Best Job in the World. Good luck.',
#        ' WOW.How sweet!',
#        ' Thank you  How`s your daughter? And by the way, how did you get 1017 followers? :O',
#        'Follow Friday is a bit hard to do when my work kicks in on Fridays',
#        ' good morning misfit *passes you Tylenol*',
#        ' WOOOOOOOOOO   are you coming to Nottingham at any point?  lovelovelove<3',
#        "try to play John Travolta`s 'Grease Lightning' bassline.. it`s cool",
#        'So from this moment foward, imma have to spend my money wisely. No dress and shoe shopping every week. No more pigging out @ my fav rest.',
#        ' Enjoy! Family trumps everything',
#        ' Ooh, jealous. I just have yoghurt and some carrots.',
#        'Yes... today is Star Wars Day!    May the 4th be with you!',
#        'Just got back from school! Ugh I don`t want to go to the dance tonight',
#        '_Guy In the past it was ok but since iï¿½ve got my own appartment, my own car........itï¿½s very difficult to save the money',
#        ' saw your pics, so awesome!',
#        'Sleeeep. Good day, nice night, comfy bed.',
#        'Just woke up. Gonna have a shower and go to Nan`s for Mother`s day lunch. Happy Mother`s day',
#        '_Kaufer You cant argue w/them, as they actually have zero things to complain about so they make stuff up',
#        ' oh ... you`ve been superseeded?  not good enough',
#        ' this week has dragged a bit for me too  have an essay to write about the seaside then Im seeing eddie izzard tonight x',
#        'Fighting with Nagios configuration.  Great tool but the config is a bit of a labour',
#        ' : Sir ! Everything Will Be Great InShaa`Allah',
#        'Stupid liars. Glad they are ignorant, because I had a blast!!',
#        'What a gorgeous day!! And I`m going to be stuck in a lab for the next 9 hours or so',
#        ' wow, that`s good', ' TY sweetheart',
#        ' Oh dear, what a rotten life you lead, NOT!',
#        ' Hello, yourself. Enjoy London. Watch out for the Hackneys. They`re mental.',
#        'btw ian watkins has stopped following me  so i am a wee bit pissed off!',
#        ' I`m going big weekend  cant wait to see u! x',
#        'so tired from school and work. shower than neighboures.',
#        ' Well it`s nice to `see` you. Have a great day and tweet again soon',
#        'Friday is not treating me well so far.',
#        'Fuuuuuuuudgeee I burned my finger with oil! It hurts',
#        ' copy & paste **** **** tosser piss flap a 10000000000 times !!!!',
#        'Starting my 2nd shift! Im going to miss like an hour of the lakers game!',
#        '  hope yer ok hunny',
#        '_raven oh, I`m skeptical too. I just think it`s the best thing he could have said under the circumstances',
#        ' yeah but there are like 5,000 types of snakes..and it`s wicked wicked wicked hot...and idk. i don`t think i`d like it',
#        'Much to my surprise, I was using my credit card before the crack dawn to do some serious online gambling. One problem: it wasn`t me.',
#        'I wanted to see the story on ACORN tonight on Glen Beck but I missed it',
#        ' Yeah it was great to be outside without rain/snow & cold air! Love the sunny days',
#        'WiSHiNG ALL THE MOTHERS A HAPPY MOTHER`S DAY',
#        'It`s raining cats and dogs in Gda?sk today , looks nice `though through a window',
#        'In Y!M, when you sign in and sign out repeatedly, you`re not annoying.',
#        '  Is competition around the corner? if not take it slow for at least a week. Twisted my ankle back in jc, awfully painful.',
#        'spent a little too much $ at Wombat, but it`s cool `cuz it was time to take care of Tamara good.  YAY!',
#        'I`m very upset right now, like I can`t even formulate a complete thought....',
#        'Why can`t I make a phone call! I hate this anxiety ****. Someone cure me',
#        " I`m thinking the 'Chevrolet Doom' would be fitting for GM",
#        'Just found a tink cover for a wii remote but the people i know dont have a wii  fail',
#        'oh my gosh!!! hollyoaks was so sad tonite',
#        'is hungryyyyyyy!! going to eat traditional indian food...the pakistani way. woowoo!  hahaha! >[_()\\/3',
#        'I am probably spamming my follower`s account.',
#        'This wind is crampin` my style. I have a section of my yard that won`t get any water. I`d move the sprinkler, but it`s surrounded by mud.',
#        ' I miss rollerblading down Shoreline.',
#        'Just finished Church. Happy Mother`s Day!',
#        ' 5 seasons that`s it? Sorry just noticed in ur previous update. My sis isn`t gonna be happy',
#        'Hope all the Mum`s out there had a Mother`s Day with love, close family & friends.',
#        'No one wants to sit with me at lunch  I guess I`ll just bury my head in my laptop and continue to be anti-social.',
#        'found rollo! and got happy  hmmm.. guess i really do need to be inserted back into the matrix 0_o',
#        ' you and  are both baitersss  hope tonight is fun!',
#        'Gorgeous day!  Worked the Master Gardener plant sale, trimmed smoke bushes, and now to do some writing.',
#        ' so sad u cancelled silverstone show  better see u in sandown park!',
#        ' The sight of it made my afternoon',
#        'http://www.bodybuilding.com/fun/richardchan.htm OMFG this dude looks well `ard! He puts me to shame...',
#        ' thank you isay  kamusta ang bulacan historical gimmick at ang gilmore shopping trip?',
#        ' ****. it should be recoverable. it`s just the boot part that`s messed up. grr argh. my business was on there.',
#        ' I think that`s what`s wrong with me.  Stuffed up and when I breathe in it feels like a sore throat',
#        ' YAY to som1 i no on twitter...slowly slowly rest of the grade will come around...hah  i hope ur ready for my constant tweets!!',
#        ' OMG are u still naked 1313 XDD omg i miss you so muuch',
#        ' Don`t worry. You`ll be 38 soon',
#        '  I do not mean to laugh but a little giggle did come out - sorry',
#        'Plane tickets to UK and everywhere in Europe are BEYOND cheap (for June-Oct!!), but there`s NO gig in the near future announced yet',
#        'rented bikes + unknown trail with random bumps + big hills + kids = one beat up little girl. Not a good day on the B family vacation.',
#        ' had  a little family party tonight   hope it rocked',
#        '_peter let`s smoke and watched dazed and confused. that`s a perfect pizza movie too',
#        'I had 2 buy a new washer, bought the dryer 2.  Dryer labeled electric but is gas   GRRR.  Now we have 2 load it up tomorrow 2 return it.',
#        'Watching George Lopez. Went to my school and played some basketball. Today was pretty nice. And HOT!',
#        'Alexxx Im gona miss you today. Im so sad, noooooooo',
#        ' My public talk in July got canceled and I don`t know why.',
#        ' WHOO HOO. Congrats on getting under 200lbs',
#        ' that truely is sad news to hear  we are all created equal, so sad to know our neighbors are such prejudice people',
#        'FreeSat`s coverage (Sky dish) is really, really bad at the moment, blocks all over the place, really annoying!',
#        ' I`d love that. And, don`t think of it as easy. Think of it as enthusiastic.',
#        'Waiting for Natie to come online I miss him.',
#        'I can`t breathe well but turns out I`m not crazy.  Just inflammed lungs',
#        'This has been a dismal week.',
#        ' Just try to do your best. I hope you don`t get laid off.',
#        'Really missing hockey already.  Off for a night in Dtn Naperville.  Can`t wait for the day off tomorrow,  I have to work Sunday.',
# ...
#        ' FAILlllllllll  whenever ur freee then?',
#        'what a beautiful morning! nice to be out',
#        'Lost at bowling again  why do i suck', ' i like OGBERRY',
#        ' I just started watching 30 Rock too, borrowed seasons 1 and 2 from my dad   so good.',
#        ' haha.. you were actually in violations of someone`s trademark?! okay..  Yeah, I went to bed at 4 and I had to be up at 6. :[',
#        ' http://twitpic.com/4vuuy - thats the most colorful thing ive seen all day,wow.',
#        ' The problem is that I`m not finished with it  But I have logged in mass hours this week on it. And i`m not being paid! POP!',
#        'A sunny morning in the Big K, with lawns to mow and a 2 mile to run to attempt, urgh',
#        ' Thanks for the shoutout', '  hope your day gets better soon!!',
#        'Watched GossiP.Girl. Dan`s so funny, haha.',
#        ' yes super lakas ng ulan. buti nalang i have a red bandana, body ko lang ang wet look  hahah!',
#        'lost HIATUS noooooooooooooooooo D: back to school tomorow. back in 10TY  ()',
#        'melissa_leah: my car wont start.......',
#        'Never commute in the rain. The people get so much meaner to you.',
#        ' I`d love to!!',
#        ' maybe one day I can be on your favorite producers list  lol',
#        'aww, jon ryan bob and greta in one picture? how adorable  and it brightens my morning, ty jon walker',
#        'Bushidokan class got canceled.   I`ll just have to sign up for karate someplace else!!',
#        ' Aw...poor thing.',
#        'and this terrible cartoon that`s supposed to be mexican.',
#        ' thanks  lyxxx', ' Happy May Day and Star Wars Day',
#        '_ERON Effy breaks my heart.',
#        ' That is super sad   How is Bart etc holding up?',
#        ' my little felted thing looks like an incestuous by- product of two of your lovelies',
#        '  BUT THEY ARE EXPENSIVE.', 'thanks !!my real name is nadia',
#        ' Happy birthday!',
#        ' - Sorry only just seen this - how strange it seems only to happen from my iPhone - perhaps it is a problem with Twitterific',
#        'happy mother`s day!',
#        'Omg i`m going to robinson with tyler wfm. And i freakin miss anthony  ugh today kinda sucks. Lex<3',
#        'its my burfday and i`m all alone',
#        'OMG I would sooooo make dis show number one n da ratings',
#        ' wats gooood !! miss yall already',
#        'Good days with good friends make me not regret living',
#        'My whole immediate will be in the same city until some point tomorrow afternoon. This is monumental',
#        'goooodnight everyone!  and Happy Mothers Day to all the mothers out there.',
#        " Yes...met Jon last yr at an interesting 'Questionning Agile' Agile 2008 session.  Don`t see him on this yr`s schedule.",
#        'Why are young people attracted to trouble? this makes me sad!  ,<3 kMv',
#        ' Enjoy the coffee. We miss you, petite puce (adica Puricel in franceza)',
#        ' nice to have you back',
#        'Just spent the last two hours playing L4D with babe  Had HELLA fun. I love him <3',
#        ' aaawww  no worries fresh start to work on growing it out again',
#        ' so sorry about that  I have the same issues...LOL. My weekend started about an hour ago!!!',
#        ' jealous  it looks like schindler`s list in toronto',
#        'outta the shower, too bad justin couldn`t spend the night.  haha',
#        ' When balancing a chair on my chin in the sixth form common room got nothing but sneers, I hung those balls up for good',
#        ' I am using iMovie 08 and it`s still not bad. I am afraid to hear what is wrong with 09',
#        '  awesome! All deserved I`m sure. Miss the Crabs games',
#        'Another HD - my lecturer was gob smacked by how good our presentation was',
#        '@ Little_Ren is lovely lovely, and so niceee',
#        ' im sure jont wont mind sharing',
#        ' lmao yeaa iight n u shuld put tha c.b flick up w. **** on ur head .. juss a joke',
#        'Where are all you Motivated/Determined/wannabe sexy successful young professionals!??! I might really have to join a BNI if there is no1!',
#        'My wedding next Thursday and I`m ill',
#        '  I`m SO jealous! I don`t know when I`ll be able to see Conan.',
#        'ahhh fusterated',
#        'watching W. with jas. i love my brother he`s my best friend',
#        ' o can`t work that one out  pain in the **** them spammers',
#        ' *reads phone book* Hugh Clancy, Hugh Claments...Nope, no Hugh Clap.  Poor Holly, though she`ll grab pity votes like a shark.',
#        'is sad that she is not seeing Basshunter at Metroplex this weekend',
#        ' I know, i know...  -hugs-',
#        'CCï¿½s video for Long Gone premiers today on yahoo, dont miss it: http://new.music.yahoo.com/videos/premieres/ AWESOME video and version',
#        '**** it. Totally gutted I decided not to go out tonight. Roni Size is DJing',
#        ' Yeah! Thanks! I`ll be back in soon to see what ya got!',
#        'Zach G. gets an extensive profile in this weekend`s NY Times Magazine. The chances of us falling in love are getting fewer and fewer.',
#        ' As opposed to twitter, where all we can do is talk to people.  SL is fun. I already have way too many ways to distract myself.',
#        ' I am definitely ready... actually ahead of you... I already have a sun tan and I was out at the beach yesterday.',
#        '  I don`t think I like this Roy Williams who dissects frogs while still alive >  You look like Chachi from Happy Days',
#        'i donbt like to peel prawns, i also dont like going shopping, running out of money and crawling round the car looking for more',
#        ' me too. I hate my computer so much..',
#        'Screw the reviews, I thought Wolverine was awesome. But not enough Dominic Monaghan for my liking.',
#        'goooooddd morning tweets!!  week three OF my workout. did i mention i got my new glasses yesterday?!?',
#        ' which case? I got a new one last week and I`m not thrilled at all with mine.',
#        ' have a safe trip joshy poo.......you`ll knock them dead at your speech',
#        ' it is ****...u have dissappointed me that past few days',
#        'going to bed its late and I have headache',
#        'egh blah and boooooooooooo i dunno wanna go to work  HANGOVERS SUCKKKKKK Im a drunk mess!',
#        'If you followed us recently, PLEASE dont be offended that we haven`t followed back. We hit our limit.   Hopefully we will be free soon.',
#        'im an avid fan of **** magazine and i love your magazines',
#        'I WANT RED CRUISERS!!  i don`t like the other ones. LMFAO!',
#        ' She`s unassuming and unpretentious. She`s just, as. I suppose that`s why she`s so endearing--because we can relate to her',
#        ' I love to! But I`m only available from 5pm.  and where dear? Would love to help  convert her vids.ï¿½',
#        ' fine! Going to do my big walk today 20 or so miles',
#        'Sleepy Tabz is heading to bed.  Fun night! Listened through the next episode of Joss`d!',
#        'i lost all my friends, i`m alone and sleepy..i wanna go home',
#        ' What`s sad is that I actually had to google that term. That sucks, tho.',
#        'Unfortunatley, AerLingus no longer fly to Copenhagen so we`re have to fly Ryanair to Billund and drive up to Copenhagen one of the days!',
#        'What better way to spoil mum than to let her kick back and relax over a nice meal and a bottle of her favorite wine? Our wine was a red',
#        'Aw. Torn ace of hearts  #Hunchback', ' romance zero is funny',
#        'Candle wax is very enjoyable.',
#        'happy mother`s day to all moms out there...',
#        'Bah a coworker ran into work late and her bag smacked into my knee  it really hurts now',
#        ' http://twitpic.com/4jaz5 - Cool... luv it',
#        'first night in myers. just not the same w/out lydia!  but i`m actually excited about this summer!',
#        'juss came backk from Berkeleyy ; omg its madd fun out there  havent been out there in a minute . whassqoodd ?',
#        'On the way to Malaysia...no internet access to Twit',
#        'http://twitpic.com/66xlm -  hate when my PARKED car gets hit',
#        'Went to sleep and there is a power cut in Noida  Power back up not working too',
#        'Few Bevvies 2day in twn..great on a day off!!',
#        'I`m going home now. Have you seen my new twitter design? Quite....heavenly isn`****?',
#        ' good morning',
#        'Playing Ghost Online is really interesting. The new updates are Kirin pet and Metamorph for third job.  Can`t wait to have a dragon pet',
#        'should be sleeping.  lost my voice a couple day ago.',
#        'URL in previous post (to timer job) should be http://bit.ly/a4Fdb. I`d removed space which messed up URL.  ^ES',
#        ' its the best show EVER!', '  I`m sorry.',
#        '  #lichfield #tweetup sounds like fun  Hope to see you and everyone else there!',
#        'I AM SUCH A CREEPER  I feel disappointed because of it. **** my cyberstalking skills   the internet = no more privacy.',
#        'My back hurts...really bad',
#        'Born and raised in NYC and living in Texas for the past 10 years!  I still miss NY',
#        'i`m soooooo sleeeeepy!!! the last day o` school was today....sniffle....',
#        '_Laurie sending love, blessings & healing thoughts to you & family  peace',
#        'A little happy for the wine jeje ok it`sm my free time so who cares, jaja i love this day',
#        ' That`s very funny.  Cute kids.',
#        'i hope unni will make the audition . fighting dahye unni !',
#        'Happy monday  up and about going to tavares today. Hope everyone has a blessed day!',
#        ' Had parent teacher thing yesterday!! So boring going to skl on saturday!!  lol',
#        ' If it is any consolation I got my BMI tested hahaha it says I am obesed  well so much for being unhappy for about 10 minutes.',
#        'My modem has been offline for a week now... God bless the 3g network. Tim just left... Again!! May schedule has been brutal',
#        'im thinking that im going to have fun tonight....and maybe some changes are coming',
#        'mannnn..... _ got an iphone!!! im jealous....  http://bit.ly/NgnaR',
#        ' We never miss ICarly - my son has a huge crush on Miranda',
#        'holy smokes! star trek was freaking awesomeeeee',
#        ' CASEY`S GONE?!?! BUT WHY?! So, she piddled a little on the carpet. She`s prolly freaked cause it`s new. Can we get her back?',
#        ' hahaa your awesomee !',
#        ' hemp cloth is marvelous but unfortunately no',
#        'Walking to class. I hate not having a bike....especially mine.',
#        'graduation is done  im a little sad.. anyone want to hang out???',
#        ' We saw that in none 3D - the baddie`s the best',
#        'Not looking forward to next week: Maths, Geography, English and French exams, totalling 7 hours',
#        ' Well what im working on isn`t QUITE ready to post about publicly (still beta testing) but its a cool new script I coded',
#        ' SWEEEEET - San Fran is awesome!!!!  Love it there',
#        'failed inspection. Did you know you can pass wo/oven, but not wo/anti-tip bracket, which is only sold w/oven? This is worse than taxes.',
#        ' Poor you  Get outside and sleep in the garden, the sun will do you good. But don`t forget suncream!!!',
#        'waiting for sleeping pills to kick in... gonna be so tired at work tomorrow',
#        'i realy wanted to go out cause its so nice but everybodys busy',
#        'Feeling smooth like chrome',
#        'Thank you, Afrin Nasal Spray! Also, I got a giant teacup tonight!',
#        " Awesome.  I`m down in Ocean Beach (if you know where that is.) By the way. 'YourBiggestFan' I`m a re-al big fan of you-rs.",
#        ' woof, I wish I was allowed to go',
#        ' haha I do not know how to work blip apart from the obvious! thanks for reblipping my song  have a nice day ****',
#        'So many tests todayyy  I don`t feel confident about anyy.',
#        '4am. And Im on the beach. Pretty',
#        "1 week post my'horrible, traumatic jumping cholla accident.'-cholla`s next dirty trick:pieces are starting to emerge from my hand! Ouch!",
#        'Aww, I love my daddy! He works 7 days a week almost all day and still tries to go to SF with all of us',
#        'i miss you bby      wish you were going tomorrow to make me do good.',
#        'decided 2 trans frm relaxed 2 natural hair but i wish my whole head looked like my roots.  Age of the instant gratification....',
#        ' a celtics-lakers rematch sounds better don`t you think? lol',
#        ' Nice to see you tweeting!  It`s Sunday 10th May and we`re celebrating Mother`s Day here today. So be nice to yer Mom',
#        'WOW, i AM REALLY MiSSiN THE FAM(iLY) TODAY. BADDD.',
#        'happy mother`s day to all the mothers in the world.',
#        ' why are you sad?',
#        ' Haha I know, I cant handle the fame!  and thank you!',
#        '35mins through the 1hr 20mins Google Wave demo, that looks a lot of fun, would love to test it though.  http://bit.ly/WnMSc',
#        'These kids are terrible! If I was in Good Evans, I`d call Childline',
#        '  He`s awesome... Have you worked with him before? He`s a good friend.',
#        'missed all the awesome weather, because she was in a movie!',
#        'Still no reply from  about my SimFinger problem  So no iRape parody video until I get a response, sorry guys',
#        'JONAS BROTHERS - Live to party.                It`s rocking so hard     I love the song,',
#        ' hey mia!  totally adore your music.  when will your cd be out?',
#        ' yes! sober HAHAHA tanghaling tapat dude! haha WILD. i don`t knowwww  plan plan  before you go to US!',
#        ' Not a prob hun',
#        'Shopping. Cleaning. BMFing. Webcam chatting with nephews. Nothing spesh, but a good bank holiday Monday nonetheless',
#        ' THANK YYYYYYYYYOOOOOOOOOOUUUUU!',
#        ' those splinters look very painful...but you were being very heroic saving mr. Pickle',
#        ' lucky kid...i so wanna see loserville  pity im in oz....',
#        ' =O you need to ask him something? Lmao I love him too',
#        'Sick. With a flu like thing.',
#        ' I`m sad that I missed you guys last night!',
#        'is back home now      gonna miss every one',
#        ' Journey!? Wow... u just became cooler.  hehe... (is that possible!?)',
#        ' Sooo SAD I will miss you here in San Diego!!!',
#        'lost my tooth 2day whilst i was eating gum...oww',
#        'really hopes her car`s illness is not terminal...',
#        'i want to go to music tonight but i lost my voice.',
#        'Oh, I HELLA forgot to say my official good morning  Like to hear it? Here it go! Goooooooooooood Morrrrrrrrning Twitterville! Lol',
#        ' yeah I was thinking about that ,ahaha',
#        'im soo bored...im deffo missing my music channels',
#        ' I miss my neice  can`t wait to see her bad n grown ****! Lol',
#        ' Sons of ****, why couldn`t they put them on the releases we already bought',
#        'my boss is bullying me...',
#        'My Sharpie is running DANGERously low on ink',
#        'i`ve been sick for the past few days  and thus, my hair looks wierd.  if i didnt have a hat on it would look... http://tinyurl.com/mnf4kw',
#        '  WHAT ABOUT ME ??  I VOTE EVERY DAY FOR YOU !!!!!',
#        ' what interview! leave me alone',
#        ' S`ok, trying to plot alternatives as we speak *sigh*',
#        'I`m not sleeping at all until  accepts my appology',
#        ' nite nite bday girl  have fun at concert',
#        '  that`s why I need to be there...To represent the Blackberries',
#        'I really really like the song Love Story by Taylor Swift',
#        '2am feedings for the baby are fun when he is all smiles and coos',
#        'or even NOOOOO NOT THE SECRET NAMEREBECCA PLEASE',
#        ' I VOTED!!! do u have a personal myspace? i keep talking to fakes   i <3 you. u helped me thru the hrdest time of my life! (: x',
#        'today was the last day of high school for me and i ended up going home sick! ... stupid dead rats',
#        'who watched X-men origins: wolverine? i totally loved it! haha',
#        'I`m starving!! This diet is killing me but I can`t eat after 8pm'],
#       dtype=object)

# %%
sample  = results_df[(results_df.supervised_model=='distilbert-base-uncased-finetuned-sst-2-english') & (results_df.pgi > .9)].iloc[0]#(results_df.texts== 'im soo bored...im deffo missing my music channels')].iloc[1]
sample
#by_text_and_model(results_df, cols, sample)
# Out:
# gold_label                                                              negative
# texts                                       Two months ago, I became irrelevant.
# selected_text                                                        irrelevant.
# supervised_model                 distilbert-base-uncased-finetuned-sst-2-english
# expl_framework                                                            random
# predicted_label                                                         negative
# predicted_score                                                        0.9963223
# explanations                   [(two, 0.4613506443337121), (months, -0.975920...
# fa(k=4)                                                                      0.0
# rank_correlation                                                       -0.507093
# iou                                                                          0.0
# pgi                                                                     0.982256
# pgu                                                                     0.000043
# len_selected_text                                                              2
# explanations_top_k_weighted    [(,, 0.38230997308793846), (ago, 0.43392385670...
# explanations_top_k                                         [,, ago, two, became]
# good_prediction                                                             True
# good_model                                                                  True
# Name: 10388, dtype: object

# %%
# We can see at an individual level how an explanation changes across methods given a fixed model

# WE can see from above that: 
- FA is directly affected by the length that we select in K (e.g. the larger the K the higher the chance the word will be in the explanation) and at the same time, 
- FA and IOU are highly affected by the choice of K selected as hyperparameter. In this case where the gold explanation is one word, we can see that as long as that 
single word is among the top K, FA and IOU will give the top performance (1). On the other side, if explanations tend to be large and K rather small, then FA or IOU
max value will be lower because there is no way the overlap is full.

On the otherside, if we look at PGI and PGU, while it is stil dependant on K, 

by_text_and_model(results_df, cols, sample)
# Out:
#                                       supervised_model expl_framework  \
# 10388  distilbert-base-uncased-finetuned-sst-2-english         random
# 10368  distilbert-base-uncased-finetuned-sst-2-english            dls
# 10369  distilbert-base-uncased-finetuned-sst-2-english            lga
# 10370  distilbert-base-uncased-finetuned-sst-2-english            lig
# 10372  distilbert-base-uncased-finetuned-sst-2-english      occlusion
# 10371  distilbert-base-uncased-finetuned-sst-2-english            svs
#
#       selected_text          explanations_top_k  \
# 10388   irrelevant.       [,, ago, two, became]
# 10368   irrelevant.         [became, ., ,, two]
# 10369   irrelevant.         [became, ., ,, two]
# 10370   irrelevant.  [became, irrelevant, ,, .]
# 10372   irrelevant.     [i, two, irrelevant, .]
# 10371   irrelevant.  [,, months, irrelevant, .]
#
#                                             explanations  fa(k=4)  iou  \
# 10388  [(two, 0.4613506443337121), (months, -0.975920...      0.0  0.0
# 10368  [(two, 0.46561462), (months, 0.13424799), (ago...      0.0  0.0
# 10369  [(two, 0.6972257), (months, -0.04851095), (ago...      0.0  0.0
# 10370  [(two, 0.05483362303959182), (months, 0.051141...      0.0  0.0
# 10372  [(two, 0.074054696), (months, 0.027286679), (a...      0.0  0.0
# 10371  [(two, -0.04987836), (months, 0.012460556), (a...      0.0  0.0
#
#             pgi       pgu
# 10388  0.982256  0.000043
# 10368  0.163647  0.000109
# 10369  0.059508  0.000709
# 10370  0.050694  0.000160
# 10372  0.093753  0.000435
# 10371  0.962170  0.000024

# %%
# Choosing a sample randomly for demo purposes
sample  = results_df[results_df['pgi'] > .95].iloc[16]
sample
# Out:
# gold_label                                                              negative
# texts                                   seems to have disappeared out of my life
# selected_text                           seems to have disappeared out of my life
# supervised_model                 distilbert-base-uncased-finetuned-sst-2-english
# expl_framework                                                            random
# predicted_label                                                         negative
# predicted_score                                                       0.99780995
# explanations                   [(seems, -0.025034509589640264), (to, -0.13220...
# fa(k=4)                                                                      1.0
# rank_correlation                                                             NaN
# iou                                                                          0.5
# pgi                                                                     0.983467
# pgu                                                                     0.001079
# len_selected_text                                                              8
# explanations_top_k_weighted    [(life, 0.43994808515600314), (of, 0.470554219...
# explanations_top_k                                   [life, of, my, disappeared]
# good_prediction                                                             True
# good_model                                                                  True
# Name: 11492, dtype: object

# %%
by_text_and_model(results_df, cols, sample)
# Out:
#                                       supervised_model expl_framework  \
# 11492  distilbert-base-uncased-finetuned-sst-2-english         random
# 11472  distilbert-base-uncased-finetuned-sst-2-english            dls
# 11473  distilbert-base-uncased-finetuned-sst-2-english            lga
# 11474  distilbert-base-uncased-finetuned-sst-2-english            lig
# 11476  distilbert-base-uncased-finetuned-sst-2-english      occlusion
# 11475  distilbert-base-uncased-finetuned-sst-2-english            svs
#
#                                   selected_text            explanations_top_k  \
# 11492  seems to have disappeared out of my life   [life, of, my, disappeared]
# 11472  seems to have disappeared out of my life          [out, to, seems, my]
# 11473  seems to have disappeared out of my life          [out, of, to, seems]
# 11474  seems to have disappeared out of my life    [of, to, out, disappeared]
# 11476  seems to have disappeared out of my life        [life, seems, to, out]
# 11475  seems to have disappeared out of my life  [disappeared, have, out, to]
#
#                                             explanations  fa(k=4)  iou  \
# 11492  [(seems, -0.025034509589640264), (to, -0.13220...      1.0  0.5
# 11472  [(seems, 0.30501643), (to, 0.18124332), (have,...      1.0  0.5
# 11473  [(seems, 0.5191091), (to, 0.23391642), (have, ...      1.0  0.5
# 11474  [(seems, 0.11179824175459388), (to, 0.33411264...      1.0  0.5
# 11476  [(seems, 0.14159079), (to, 0.4817459), (have, ...      1.0  0.5
# 11475  [(seems, -0.005170945), (to, 0.5655437), (have...      1.0  0.5
#
#             pgi       pgu
# 11492  0.983467  0.001079
# 11472  0.029305  0.000256
# 11473  0.105053  0.000032
# 11474  0.992188  0.001000
# 11476  0.002109  0.989223
# 11475  0.994696  0.000404

# %%
# Top k explanations for a given text an model
by_text_and_expl_method(results_df, cols, sample)
# Out:
#                                       supervised_model expl_framework  \
# 10295  finiteautomata/bertweet-base-sentiment-analysis         random
# 10294    cardiffnlp/twitter-xlm-roberta-base-sentiment         random
# 10293        cardiffnlp/twitter-roberta-base-sentiment         random
# 10292  distilbert-base-uncased-finetuned-sst-2-english         random
#
#       selected_text    explanations_top_k  \
# 10295   rofl uh huh       [huh, rofl, uh]
# 10294   rofl uh huh     [▁uh, h, ▁ro, fl]
# 10293   rofl uh huh  [Ġhuh, Ġuh, Ġro, fl]
# 10292   rofl uh huh   [huh, uh, ro, ##fl]
#
#                                             explanations  fa(k=4)  iou  \
# 10295  [(rofl, 0.38159284052936404), (uh, 0.778159636...     1.00  1.0
# 10294  [(▁ro, 0.38159284052936404), (fl, 0.7781596367...     0.75  0.8
# 10293  [(Ġro, 0.38159284052936404), (fl, 0.7781596367...     0.00  0.0
# 10292  [(ro, 0.38159284052936404), (##fl, 0.778159636...     1.00  1.0
#
#             pgi       pgu
# 10295  0.057074  0.057074
# 10294  0.119038  0.050585
# 10293  0.341256  0.341256
# 10292  0.737654  0.737654

# %%
# Top k explanations for a given text and expl method
by_text(results_df, cols, sample)
# Out:
#                                       supervised_model expl_framework  \
# 10295  finiteautomata/bertweet-base-sentiment-analysis         random
# 10294    cardiffnlp/twitter-xlm-roberta-base-sentiment         random
# 10293        cardiffnlp/twitter-roberta-base-sentiment         random
# 10292  distilbert-base-uncased-finetuned-sst-2-english         random
# 10287  finiteautomata/bertweet-base-sentiment-analysis            dls
# 10282    cardiffnlp/twitter-xlm-roberta-base-sentiment            dls
# 10277        cardiffnlp/twitter-roberta-base-sentiment            dls
# 10272  distilbert-base-uncased-finetuned-sst-2-english            dls
# 10288  finiteautomata/bertweet-base-sentiment-analysis            lga
# 10283    cardiffnlp/twitter-xlm-roberta-base-sentiment            lga
# 10273  distilbert-base-uncased-finetuned-sst-2-english            lga
# 10278        cardiffnlp/twitter-roberta-base-sentiment            lga
# 10274  distilbert-base-uncased-finetuned-sst-2-english            lig
# 10289  finiteautomata/bertweet-base-sentiment-analysis            lig
# 10284    cardiffnlp/twitter-xlm-roberta-base-sentiment            lig
# 10279        cardiffnlp/twitter-roberta-base-sentiment            lig
# 10276  distilbert-base-uncased-finetuned-sst-2-english      occlusion
# 10281        cardiffnlp/twitter-roberta-base-sentiment      occlusion
# 10286    cardiffnlp/twitter-xlm-roberta-base-sentiment      occlusion
# 10291  finiteautomata/bertweet-base-sentiment-analysis      occlusion
# 10290  finiteautomata/bertweet-base-sentiment-analysis            svs
# 10275  distilbert-base-uncased-finetuned-sst-2-english            svs
# 10280        cardiffnlp/twitter-roberta-base-sentiment            svs
# 10285    cardiffnlp/twitter-xlm-roberta-base-sentiment            svs
#
#       selected_text    explanations_top_k  \
# 10295   rofl uh huh       [huh, rofl, uh]
# 10294   rofl uh huh     [▁uh, h, ▁ro, fl]
# 10293   rofl uh huh  [Ġhuh, Ġuh, Ġro, fl]
# 10292   rofl uh huh   [huh, uh, ro, ##fl]
# 10287   rofl uh huh       [rofl, uh, huh]
# 10282   rofl uh huh   [▁ro, ▁hu, fl, ▁uh]
# 10277   rofl uh huh  [Ġro, Ġuh, fl, Ġhuh]
# 10272   rofl uh huh   [uh, huh, ##fl, ro]
# 10288   rofl uh huh       [uh, huh, rofl]
# 10283   rofl uh huh     [h, ▁hu, ▁ro, fl]
# 10273   rofl uh huh   [uh, ##fl, huh, ro]
# 10278   rofl uh huh  [Ġro, fl, Ġuh, Ġhuh]
# 10274   rofl uh huh   [huh, uh, ##fl, ro]
# 10289   rofl uh huh       [uh, rofl, huh]
# 10284   rofl uh huh    [▁uh, ▁hu, ▁ro, h]
# 10279   rofl uh huh  [Ġhuh, Ġro, Ġuh, fl]
# 10276   rofl uh huh   [huh, uh, ##fl, ro]
# 10281   rofl uh huh  [Ġhuh, fl, Ġro, Ġuh]
# 10286   rofl uh huh     [▁hu, fl, h, ▁ro]
# 10291   rofl uh huh       [rofl, uh, huh]
# 10290   rofl uh huh       [rofl, uh, huh]
# 10275   rofl uh huh   [huh, uh, ##fl, ro]
# 10280   rofl uh huh  [Ġhuh, fl, Ġro, Ġuh]
# 10285   rofl uh huh   [▁uh, ▁ro, ▁hu, fl]
#
#                                             explanations  fa(k=4)  iou  \
# 10295  [(rofl, 0.38159284052936404), (uh, 0.778159636...     1.00  1.0
# 10294  [(▁ro, 0.38159284052936404), (fl, 0.7781596367...     0.75  0.8
# 10293  [(Ġro, 0.38159284052936404), (fl, 0.7781596367...     0.00  0.0
# 10292  [(ro, 0.38159284052936404), (##fl, 0.778159636...     1.00  1.0
# 10287  [(rofl, 0.0), (uh, 0.023739992), (huh, 0.13813...     1.00  1.0
# 10282  [(▁ro, 0.0), (fl, 0.48218614), (▁uh, 0.7491187...     1.00  0.8
# 10277  [(Ġro, 0.0), (fl, 0.39204517), (Ġuh, 0.3831575...     0.00  0.0
# 10272  [(ro, 0.5985419), (##fl, 0.08779206), (uh, -0....     1.00  1.0
# 10288  [(rofl, 0.44999063), (uh, 0.1422347), (huh, 0....     1.00  1.0
# 10283  [(▁ro, -0.09114122), (fl, 0.20295222), (▁uh, -...     1.00  0.8
# 10273  [(ro, 0.7088451), (##fl, -0.0830671), (uh, -0....     1.00  1.0
# 10278  [(Ġro, -0.5105827), (fl, -0.28635943), (Ġuh, 0...     0.00  0.0
# 10274  [(ro, 0.2679759022348862), (##fl, 0.0118919191...     1.00  1.0
# 10289  [(rofl, 0.0), (uh, -0.00010947791682639248), (...     1.00  1.0
# 10284  [(▁ro, 0.0), (fl, -0.36363673002501196), (▁uh,...     1.00  0.8
# 10279  [(Ġro, 0.0), (fl, 0.17442835647312688), (Ġuh, ...     0.00  0.0
# 10276  [(ro, 0.06153112), (##fl, -0.01855741), (uh, -...     1.00  1.0
# 10281  [(Ġro, 0.0), (fl, -0.087826625), (Ġuh, 0.08440...     0.00  0.0
# 10286  [(▁ro, 0.0), (fl, -0.21630982), (▁uh, -0.26807...     1.00  0.8
# 10291  [(rofl, 0.0), (uh, 0.37083045), (huh, 0.375704...     1.00  1.0
# 10290  [(rofl, 0.0), (uh, 0.11762057), (huh, 0.613234...     1.00  1.0
# 10275  [(ro, 0.38163695), (##fl, 0.017577935), (uh, -...     1.00  1.0
# 10280  [(Ġro, 0.0), (fl, -0.08445441), (Ġuh, 0.023131...     0.00  0.0
# 10285  [(▁ro, 0.0), (fl, 0.1788344), (▁uh, -0.0461803...     1.00  0.8
#
#             pgi       pgu
# 10295  0.057074  0.057074
# 10294  0.119038  0.050585
# 10293  0.341256  0.341256
# 10292  0.737654  0.737654
# 10287  0.057074  0.057074
# 10282  0.071310  0.105219
# 10277  0.341256  0.341256
# 10272  0.737654  0.737654
# 10288  0.057074  0.057074
# 10283  0.071310  0.105219
# 10273  0.737654  0.737654
# 10278  0.341256  0.341256
# 10274  0.737654  0.737654
# 10289  0.057074  0.057074
# 10284  0.071310  0.050585
# 10279  0.341256  0.341256
# 10276  0.737654  0.737654
# 10281  0.341256  0.341256
# 10286  0.071310  0.105219
# 10291  0.057074  0.057074
# 10290  0.057074  0.057074
# 10275  0.737654  0.737654
# 10280  0.341256  0.341256
# 10285  0.071310  0.050585
